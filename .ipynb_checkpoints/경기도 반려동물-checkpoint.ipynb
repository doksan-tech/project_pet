# %% [markdown]
# # 주제 선정 : 경기도 반려동물 빅데이터를 이용한 사업부지 선정

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
# plot에서 한글 폰트 설정(안 하면 한글이 깨져서 나옴)
font_name = matplotlib.font_manager.FontProperties(
        fname='c:/windows/fonts/malgun.ttf').get_name()
matplotlib.rc('font', family=font_name)
# 한글폰트 지정 후 음수부호를 정확하게 표시하기 위해 추가할 코드
matplotlib.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # csv가 깨져서 utf로 변환하여 다시 저장해서 꺼내 쓰는 방법을 사용했습니다.

# %%
# 자료 원본 불러오기
pop_data = pd.read_csv('주민등록인구집계현황.csv', encoding='euc-kr')
pet_data = pd.read_csv('반려동물등록현황.csv', encoding='euc-kr')
store_data = pd.read_csv('반려동물판매업체현황.csv',encoding='cp949')

# utf-8로 저장
pop_data.to_csv('utf-주민등록인구집계현황.csv', encoding='utf-8', index=None)
pet_data.to_csv('utf-반려동물등록현황.csv', encoding='utf-8', index=None)
store_data.to_csv('utf-반려동물판매업체현황.csv', encoding='utf-8', index=None)

# 인구 자료 다시 불러오기
pop_data = pd.read_csv('utf-주민등록인구집계현황.csv')
pet_data = pd.read_csv('utf-반려동물등록현황.csv')
store_data = pd.read_csv('utf-반려동물판매업체현황.csv')

# %% [markdown]
# # 동물 복지 현황
#
# 경기도에는 반려동물이 어디에 얼마나 살고 있을까?

# %%
pet_data
# Out:
#      시군명 읍면동명  등록동물수(마리)  (등록주체)시군구등록  (등록주체)대행업체등록  (등록주체)기타  (RFID종류)내장형  \
# 0    가평군  가평읍        941          NaN           NaN       NaN          596
# 1    가평군   북면        289          NaN           NaN       NaN          176
# 2    가평군   상면        399          NaN           NaN       NaN          217
# 3    가평군  설악면       1111          NaN           NaN       NaN          446
# 4    가평군  조종면        416          NaN           NaN       NaN          218
# ..   ...  ...        ...          ...           ...       ...          ...
# 724  화성시  청계동       2046         90.0        1956.0       0.0         1052
# 725  화성시  팔탄면        753         87.0         665.0       1.0          345
# 726  화성시  향남읍       5180        314.0        4863.0       3.0         2110
# 727  화성시  활초동         15          0.0          15.0       0.0            4
# 728  화성시  황계동         52         16.0          36.0       0.0           19
#
#      (RFID종류)외장형  (RFID종류)인식표  등록품종수  등록소유자수  동물소유자당등록동물수  해당동의등록대행업체수  \
# 0            294           51    NaN    85.0          NaN          3.0
# 1             93           20    NaN   185.0          NaN          0.0
# 2            153           29    NaN   243.0          NaN          0.0
# 3            612           53    NaN   625.0          NaN          1.0
# 4            161           37    NaN   274.0          NaN          1.0
# ..           ...          ...    ...     ...          ...          ...
# 724          879          115   66.0  1679.0         1.22          4.0
# 725          305          103   62.0   412.0         1.83          1.0
# 726         2584          486  103.0  3719.0         1.39          6.0
# 727           11            0    7.0    11.0         1.36          0.0
# 728           13           20   15.0    24.0         2.17          0.0
#
#         데이터기준일자
# 0    2022-06-14
# 1    2022-06-14
# 2    2022-06-14
# 3    2022-06-14
# 4    2022-06-14
# ..          ...
# 724  2022-05-31
# 725  2022-05-31
# 726  2022-05-31
# 727  2022-05-31
# 728  2022-05-31
#
# [729 rows x 14 columns]

# %% [markdown]
# ### 여러 데이터 중 중요한 자료는 지역명들과 동물의 수, 기타 몇가지라고 판단했습니다.

# %%
pet = pet_data.loc[:,['시군명','읍면동명','등록동물수(마리)','등록소유자수','해당동의등록대행업체수']]
pet
# Out:
#      시군명 읍면동명  등록동물수(마리)  등록소유자수  해당동의등록대행업체수
# 0    가평군  가평읍        941    85.0          3.0
# 1    가평군   북면        289   185.0          0.0
# 2    가평군   상면        399   243.0          0.0
# 3    가평군  설악면       1111   625.0          1.0
# 4    가평군  조종면        416   274.0          1.0
# ..   ...  ...        ...     ...          ...
# 724  화성시  청계동       2046  1679.0          4.0
# 725  화성시  팔탄면        753   412.0          1.0
# 726  화성시  향남읍       5180  3719.0          6.0
# 727  화성시  활초동         15    11.0          0.0
# 728  화성시  황계동         52    24.0          0.0
#
# [729 rows x 5 columns]

# %% [markdown]
# #### 또한 시군명이 읍면동 단위로 내려가면서 시군 단위에서의 동물의 수가 의미가 있다고 판단했습니다.
#
# - 시군명 자료만 리스트로 만들어서 지역별 동물의 수를 붙여서 데이터프레임화하였습니다.

# %%
town_num = pet.drop_duplicates(['시군명'], keep='first', inplace=False, ignore_index=True)
town = list(town_num['시군명'])
print(town)
# Out:
# ['가평군', '고양시', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시', '남양주시', '동두천시', '부천시', '성남시', '수원시', '시흥시', '안산시', '안성시', '안양시', '양주시', '양평군', '여주시', '연천군', '오산시', '용인시', '의왕시', '의정부시', '이천시', '파주시', '평택시', '포천시', '하남시', '화성시']

# %%
ani_list = []
for i in town:
    ani_sum = pet[pet['시군명'].str.contains(i)]['등록동물수(마리)'].sum()
#     ani_list.append([)
#     ani_list.append(ani_sum)
    ani_list.append([i, ani_sum])
print(ani_list)
# Out:
# [['가평군', 4017], ['고양시', 73477], ['과천시', 2974], ['광명시', 20161], ['광주시', 29042], ['구리시', 12381], ['군포시', 15480], ['김포시', 7912], ['남양주시', 42957], ['동두천시', 6998], ['부천시', 113892], ['성남시', 55728], ['수원시', 65330], ['시흥시', 30539], ['안산시', 86158], ['안성시', 19950], ['안양시', 35644], ['양주시', 54805], ['양평군', 13291], ['여주시', 5252], ['연천군', 2020], ['오산시', 14471], ['용인시', 50227], ['의왕시', 6590], ['의정부시', 58997], ['이천시', 13147], ['파주시', 24057], ['평택시', 60468], ['포천시', 11168], ['하남시', 17634], ['화성시', 48264]]

# %%
# 자료 정제
pet_df = pd.DataFrame(ani_list)
pet_df.columns = ['행정구역명', '총 동물수']
pet_df
# Out:
#    행정구역명   총 동물수
# 0    가평군    4017
# 1    고양시   73477
# 2    과천시    2974
# 3    광명시   20161
# 4    광주시   29042
# 5    구리시   12381
# 6    군포시   15480
# 7    김포시    7912
# 8   남양주시   42957
# 9   동두천시    6998
# 10   부천시  113892
# 11   성남시   55728
# 12   수원시   65330
# 13   시흥시   30539
# 14   안산시   86158
# 15   안성시   19950
# 16   안양시   35644
# 17   양주시   54805
# 18   양평군   13291
# 19   여주시    5252
# 20   연천군    2020
# 21   오산시   14471
# 22   용인시   50227
# 23   의왕시    6590
# 24  의정부시   58997
# 25   이천시   13147
# 26   파주시   24057
# 27   평택시   60468
# 28   포천시   11168
# 29   하남시   17634
# 30   화성시   48264

# %%
pet_df.plot(x='행정구역명', y='총 동물수',kind='bar')
plt.title("지역별 동물 수")
plt.xlabel('행정구역명')
plt.ylabel('숫자')
plt.show();

# %% [markdown]
# # 그렇다면 이 동물들은 얼마나 많은 사람과 살고 있을까?

# %%
pop_data
# Out:
#           연도  월 행정구역구분명        행정구역명     총 인구수     0~9세   10~19세   20~29세  \
# 0       2022  9       도        경기도    13574353  1054380  1327378  1753988
# 1       2022  9      시군     경기도 가평군      62168     3047     4471     6009
# 2       2022  9     읍면동  경기도 가평군 가평읍     19532     1062     1677     2125
# 3       2022  9     읍면동   경기도 가평군 북면      3821      126      177      224
# 4       2022  9     읍면동   경기도 가평군 상면      5688      153      244      512
# ...      ... ..     ...          ...       ...      ...      ...      ...
# 107481  2008  1     읍면동  경기도 화성시 팔탄면      9900      869      869     1694
# 107482  2008  1     읍면동  경기도 화성시 향남읍     21100     2828     2288     3151
# 107483  2008  1     읍면동  경기도 화성시 향남읍     21100     2828     2288     3151
# 107484  2008  1     읍면동  경기도 화성시 화산동     23684     3727     2793     3515
# 107485  2008  1     읍면동  경기도 화성시 화산동     23684     3727     2793     3515
#
#          30~39세   40~49세  ...  10~19세 (여)  20~29세 (여)  30~39세 (여)  40~49세 (여)  \
# 0       1880750  2286448  ...      646493      828547      904145     1122988
# 1          5406     7722  ...        2175        2520        2449        3575
# 2          1804     2649  ...         784         959         845        1245
# 3           231      368  ...          90          82          99         164
# 4           389      560  ...         111         155         171         245
# ...         ...      ...  ...         ...         ...         ...         ...
# 107481     1671     1735  ...         407         606         596         717
# 107482     4316     3415  ...        1136        1444        1835        1467
# 107483     4316     3415  ...        1136        1444        1835        1467
# 107484     5424     3869  ...        1296        1699        2528        1737
# 107485     5424     3869  ...        1296        1699        2528        1737
#
#         50~59세 (여)  60~69세 (여)  70~79세 (여)  80~89세 (여)  90~99세 (여)  \
# 0          1131303      864393      435119      248574       43544
# 1             5177        6376        3551        2379         395
# 2             1590        1792        1013         732         117
# 3              309         507         288         206          39
# 4              543         718         384         240          44
# ...            ...         ...         ...         ...         ...
# 107481         579         455         373         120          23
# 107482        1107         797         622         180          34
# 107483        1107         797         622         180          34
# 107484        1079         686         419         115          19
# 107485        1079         686         419         115          19
#
#         100세 이상 (여)
# 0              1373
# 1                15
# 2                 7
# 3                 1
# 4                 0
# ...             ...
# 107481            0
# 107482            4
# 107483            4
# 107484            0
# 107485            0
#
# [107486 rows x 40 columns]

# %% [markdown]
# ### 방대한 자료에서 필요한 자료는 최신 인구수라고 판단 2022년의 9월 자료 중 행정구역 구분명이 시군인 자료들만
# ### 추렸습니다.

# %%
popu = pop_data[(pop_data['연도']==2022) & (pop_data['월']==9) & (pop_data['행정구역구분명']=='시군')]
popu
# Out:
#        연도  월 행정구역구분명      행정구역명    총 인구수   0~9세  10~19세  20~29세  30~39세  \
# 1    2022  9      시군   경기도 가평군     62168   3047    4471    6009    5406
# 8    2022  9      시군   경기도 고양시   1079277  76769  101359  144797  142834
# 56   2022  9      시군   경기도 과천시     78301   7252    7477   10114   11678
# 63   2022  9      시군   경기도 광명시    290756  21241   29236   36023   39235
# 83   2022  9      시군   경기도 광주시    388893  32763   34308   44419   55022
# 97   2022  9      시군   경기도 구리시    191011  13565   17140   25407   24761
# 106  2022  9      시군   경기도 군포시    267493  18143   25052   36251   37090
# 119  2022  9      시군   경기도 김포시    485609  52226   50418   51534   73073
# 134  2022  9      시군  경기도 남양주시    734642  61907   78547   85553   89129
# 153  2022  9      시군  경기도 동두천시     93260   5643    8397   10848    9843
# 162  2022  9      시군   경기도 부천시    801503  51652   67213  109471  111137
# 173  2022  9      시군   경기도 성남시    928267  64710   84931  125170  134343
# 228  2022  9      시군   경기도 수원시   1188234  87748  114808  181543  179237
# 277  2022  9      시군   경기도 시흥시    512721  46671   50582   68471   76611
# 297  2022  9      시군   경기도 안산시    650708  40714   60606  103790   85093
# 325  2022  9      시군   경기도 안성시    189772  12831   17799   22908   22614
# 341  2022  9      시군   경기도 안양시    549724  37733   50520   73916   78459
# 376  2022  9      시군   경기도 양주시    236142  19182   24242   27424   27622
# 388  2022  9      시군   경기도 양평군    121789   6937    9676   10446   10606
# 401  2022  9      시군   경기도 여주시    112410   6768    9333   11720   11055
# 414  2022  9      시군   경기도 연천군     42731   2479    2991    5026    4069
# 425  2022  9      시군   경기도 오산시    230028  21083   25011   30730   36694
# 432  2022  9      시군   경기도 용인시   1075877  92224  120364  136510  138616
# 474  2022  9      시군   경기도 의왕시    162137  12341   13903   22121   22633
# 481  2022  9      시군  경기도 의정부시    464358  32355   41486   63633   60029
# 496  2022  9      시군   경기도 이천시    222722  17482   21783   30853   30621
# 511  2022  9      시군   경기도 파주시    486515  42783   50540   59442   68319
# 529  2022  9      시군   경기도 평택시    569369  49711   54447   77697   87007
# 555  2022  9      시군   경기도 포천시    148469   7927   11546   17869   14581
# 571  2022  9      시군   경기도 하남시    323558  32788   29292   37922   53067
# 586  2022  9      시군   경기도 화성시    892038  99321  102360  109222  149583
#
#      40~49세  ...  10~19세 (여)  20~29세 (여)  30~39세 (여)  40~49세 (여)  50~59세 (여)  \
# 1      7722  ...        2175        2520        2449        3575        5177
# 8    175981  ...       49590       70882       71693       90624      100944
# 56    11865  ...        3668        4833        5884        6037        6823
# 63    49324  ...       14175       17320       19193       25074       24582
# 83    68394  ...       16730       20789       26395       32423       32169
# 97    31133  ...        8355       12350       12264       15557       17728
# 106   42096  ...       12094       17369       17597       21308       24232
# 119   93045  ...       24751       25096       37234       44817       34193
# 134  132532  ...       38089       41173       45023       66282       60538
# 153   13662  ...        4162        4986        4686        6626        7799
# 162  124427  ...       32814       53026       53827       61610       74108
# 173  152325  ...       41391       60967       65613       77300       77519
# 228  198380  ...       55573       86323       84688       98572       99549
# 277   92986  ...       24608       31097       35589       42744       42924
# 297  102564  ...       29464       48462       38646       49691       62913
# 325   30177  ...        8527       10256       10193       13997       15070
# 341   85682  ...       24341       35660       38020       43395       49446
# 376   39702  ...       11907       12631       13305       19348       18962
# 388   16376  ...        4615        4645        5173        8092       10200
# 401   15797  ...        4502        5285        5201        7679        9488
# 414    4707  ...        1418        1794        1720        2143        3191
# 425   44294  ...       12150       14084       16606       20670       16367
# 432  196299  ...       58653       65397       69635       99821       85579
# 474   23834  ...        6737       10507       11011       11893       15154
# 481   73273  ...       20227       31541       29277       36330       41556
# 496   35201  ...       10481       13294       14021       16929       17170
# 511   83441  ...       24655       27314       32419       40637       37425
# 529   98547  ...       26430       34310       38811       45701       43712
# 555   19384  ...        5491        7521        6385        8944       13121
# 571   58836  ...       14510       18929       26374       28340       23002
# 586  173706  ...       50219       49864       71040       81620       57825
#
#      60~69세 (여)  70~79세 (여)  80~89세 (여)  90~99세 (여)  100세 이상 (여)
# 1          6376        3551        2379         395           15
# 8         67927       35157       23140        3937          114
# 56         5019        2314        1375         323            9
# 63        20764        9739        5302         899           26
# 83        26827       12073        5872        1070           42
# 97        13257        6438        3334         501           13
# 106       18749        8356        5258         945           39
# 119       27972       14407        7329        1329           35
# 134       47333       25339       13121        2299           94
# 153        7291        4859        3094         448           15
# 162       61436       25829       14100        2579           95
# 173       62189       31771       16685        3218          112
# 228       68725       32549       17985        3192          109
# 277       25870       10991        6695        1210           46
# 297       38855       16651       10473        1873           61
# 325       13823        7541        5150         916           32
# 341       39360       17575        9806        1801           56
# 376       15925        8878        5105         905           26
# 388       12671        6800        4200         835           23
# 401       10049        5361        3659         701           23
# 414        3915        2619        1955         316           10
# 425       11329        5647        2851         455           15
# 432       59634       36706       18231        3323          121
# 474       11940        4881        2914         587           22
# 481       32353       17605        9811        1539           43
# 496       14165        7173        4600         787           23
# 511       28175       16169       10034        1767           56
# 529       30966       16238        9891        1563           58
# 555       12555        6520        4545         770           24
# 571       20442        9035        4217         895           39
# 586       39053       18089       10204        1872           47
#
# [31 rows x 40 columns]

# %% [markdown]
# ### 자료의 가독성을 위해 필요한 자료인 연도, 행정구역명, 총 인구수 자료로 추립니다.
# ### 앞에서 확보한 총 동물 수 자료와 지역명을 맞추기 위해 컬럼 자료값에서 '경기도'를 제외합니다.

# %%
population_df = popu.loc[:, ['연도','행정구역명','총 인구수']]
population_df['행정구역명'] = ['가평군', '고양시', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시', '남양주시', 
'동두천시', '부천시', '성남시', '수원시', '시흥시', '안산시', '안성시', '안양시', '양주시', '양평군', '여주시', '연천군', 
'오산시', '용인시', '의왕시', '의정부시', '이천시', '파주시', '평택시', '포천시', '하남시', '화성시']
population_df
# Out:
#        연도 행정구역명    총 인구수
# 1    2022   가평군    62168
# 8    2022   고양시  1079277
# 56   2022   과천시    78301
# 63   2022   광명시   290756
# 83   2022   광주시   388893
# 97   2022   구리시   191011
# 106  2022   군포시   267493
# 119  2022   김포시   485609
# 134  2022  남양주시   734642
# 153  2022  동두천시    93260
# 162  2022   부천시   801503
# 173  2022   성남시   928267
# 228  2022   수원시  1188234
# 277  2022   시흥시   512721
# 297  2022   안산시   650708
# 325  2022   안성시   189772
# 341  2022   안양시   549724
# 376  2022   양주시   236142
# 388  2022   양평군   121789
# 401  2022   여주시   112410
# 414  2022   연천군    42731
# 425  2022   오산시   230028
# 432  2022   용인시  1075877
# 474  2022   의왕시   162137
# 481  2022  의정부시   464358
# 496  2022   이천시   222722
# 511  2022   파주시   486515
# 529  2022   평택시   569369
# 555  2022   포천시   148469
# 571  2022   하남시   323558
# 586  2022   화성시   892038

# %%
population_df.plot(x='행정구역명', y='총 인구수',kind='bar')
plt.title("지역별 인구 수")
plt.xlabel('행정구역명')
plt.ylabel('숫자')
plt.show();

# %% [markdown]
# # 자료 병합 : 어디에 얼마나 많은 사람과 함께 많은 동물들이 살고 있는지 살펴봅시다.

# %%
p_a_sum = pd.merge(pet_df, population_df, how="outer")
p_a_sum
# Out:
#    행정구역명   총 동물수    연도    총 인구수
# 0    가평군    4017  2022    62168
# 1    고양시   73477  2022  1079277
# 2    과천시    2974  2022    78301
# 3    광명시   20161  2022   290756
# 4    광주시   29042  2022   388893
# 5    구리시   12381  2022   191011
# 6    군포시   15480  2022   267493
# 7    김포시    7912  2022   485609
# 8   남양주시   42957  2022   734642
# 9   동두천시    6998  2022    93260
# 10   부천시  113892  2022   801503
# 11   성남시   55728  2022   928267
# 12   수원시   65330  2022  1188234
# 13   시흥시   30539  2022   512721
# 14   안산시   86158  2022   650708
# 15   안성시   19950  2022   189772
# 16   안양시   35644  2022   549724
# 17   양주시   54805  2022   236142
# 18   양평군   13291  2022   121789
# 19   여주시    5252  2022   112410
# 20   연천군    2020  2022    42731
# 21   오산시   14471  2022   230028
# 22   용인시   50227  2022  1075877
# 23   의왕시    6590  2022   162137
# 24  의정부시   58997  2022   464358
# 25   이천시   13147  2022   222722
# 26   파주시   24057  2022   486515
# 27   평택시   60468  2022   569369
# 28   포천시   11168  2022   148469
# 29   하남시   17634  2022   323558
# 30   화성시   48264  2022   892038

# %%
# 자료 정렬
stat1 = p_a_sum.sort_values(by=['총 인구수','총 동물수'],ascending=False)
stat1
# Out:
#    행정구역명   총 동물수    연도    총 인구수
# 12   수원시   65330  2022  1188234
# 1    고양시   73477  2022  1079277
# 22   용인시   50227  2022  1075877
# 11   성남시   55728  2022   928267
# 30   화성시   48264  2022   892038
# 10   부천시  113892  2022   801503
# 8   남양주시   42957  2022   734642
# 14   안산시   86158  2022   650708
# 27   평택시   60468  2022   569369
# 16   안양시   35644  2022   549724
# 13   시흥시   30539  2022   512721
# 26   파주시   24057  2022   486515
# 7    김포시    7912  2022   485609
# 24  의정부시   58997  2022   464358
# 4    광주시   29042  2022   388893
# 29   하남시   17634  2022   323558
# 3    광명시   20161  2022   290756
# 6    군포시   15480  2022   267493
# 17   양주시   54805  2022   236142
# 21   오산시   14471  2022   230028
# 25   이천시   13147  2022   222722
# 5    구리시   12381  2022   191011
# 15   안성시   19950  2022   189772
# 23   의왕시    6590  2022   162137
# 28   포천시   11168  2022   148469
# 18   양평군   13291  2022   121789
# 19   여주시    5252  2022   112410
# 9   동두천시    6998  2022    93260
# 2    과천시    2974  2022    78301
# 0    가평군    4017  2022    62168
# 20   연천군    2020  2022    42731

# %%
population_df.plot(x='행정구역명', y='총 인구수',kind='bar')
plt.title("지역별 인구 수")
plt.xlabel('행정구역명')
plt.ylabel('숫자')
plt.show();

# %%
# 가독성을 위해 컬럼 순서 변경
stat = stat1[['연도','행정구역명','총 인구수','총 동물수']]
stat
# Out:
#       연도 행정구역명    총 인구수   총 동물수
# 12  2022   수원시  1188234   65330
# 1   2022   고양시  1079277   73477
# 22  2022   용인시  1075877   50227
# 11  2022   성남시   928267   55728
# 30  2022   화성시   892038   48264
# 10  2022   부천시   801503  113892
# 8   2022  남양주시   734642   42957
# 14  2022   안산시   650708   86158
# 27  2022   평택시   569369   60468
# 16  2022   안양시   549724   35644
# 13  2022   시흥시   512721   30539
# 26  2022   파주시   486515   24057
# 7   2022   김포시   485609    7912
# 24  2022  의정부시   464358   58997
# 4   2022   광주시   388893   29042
# 29  2022   하남시   323558   17634
# 3   2022   광명시   290756   20161
# 6   2022   군포시   267493   15480
# 17  2022   양주시   236142   54805
# 21  2022   오산시   230028   14471
# 25  2022   이천시   222722   13147
# 5   2022   구리시   191011   12381
# 15  2022   안성시   189772   19950
# 23  2022   의왕시   162137    6590
# 28  2022   포천시   148469   11168
# 18  2022   양평군   121789   13291
# 19  2022   여주시   112410    5252
# 9   2022  동두천시    93260    6998
# 2   2022   과천시    78301    2974
# 0   2022   가평군    62168    4017
# 20  2022   연천군    42731    2020

# %% [markdown]
# #### 특이점 : 부천시의 경우 인구는 80만밖에 안되지만 동물 수가 11만마리가 넘는다.

# %% [markdown]
# # 도시별 반려동물 관련 산업의 분포 파악

# %%
store_data
# Out:
#        시군명               사업장명     인허가일자  인허가취소일자  영업상태구분코드 영업상태명        폐업일자  \
# 0      가평군              예쁜강아지  20080909      NaN         4    말소  20220526.0
# 1      가평군             자이언트 펫  20160517      NaN         4    말소  20220526.0
# 2      가평군              메이플켄넬  20170227      NaN         4    말소         NaN
# 3      가평군               리얼펫독  20150120      NaN         4    말소  20220526.0
# 4      가평군              강아지나라  20100311      NaN         4    말소  20220526.0
# ...    ...                ...       ...      ...       ...   ...         ...
# 14449  화성시             금은이네농장  20211119      NaN         2    폐업  20220728.0
# 14450  화성시             냥이와 양이  20170530      NaN         1    휴업         NaN
# 14451  NaN  학교종이 댕댕댕(24거3849)  20200909      NaN         4    말소  20220526.0
# 14452  NaN               쁘띠살롱  20220126      NaN         4    말소  20220526.0
# 14453  NaN  학교종이 댕댕댕(24거3849)  20200909      NaN         4    말소  20220701.0
#
#           소재지시설전화번호  소재지면적정보  도로명우편번호  ...                    소재지지번주소  \
# 0               NaN      NaN      NaN  ...   경기도 가평군 가평읍 읍내리 ***-*번지
# 1      031-585-7003      0.0  12457.0  ...  경기도 가평군 청평면 대성리 ***-**번지
# 2          585-0588      0.0  12416.0  ...     경기도 가평군 가평읍 대곡리 ***-*
# 3               NaN      0.0  12467.0  ...     경기도 가평군 설악면 신천리 ***-*
# 4               NaN      NaN      NaN  ...  경기도 가평군 청평면 청평리 ***-**번지
# ...             ...      ...      ...  ...                        ...
# 14449           NaN      0.0  18562.0  ...       경기도 화성시 우정읍 운평리 ***
# 14450           NaN      0.0  18556.0  ...     경기도 화성시 서신면 홍법리 ***-*
# 14451           NaN      0.0  31560.0  ...         충청남도 아산시 법곡동 *-**
# 14452           NaN      0.0  21548.0  ...       인천광역시 남동구 구월동 **-**
# 14453           NaN      0.0  31560.0  ...         충청남도 아산시 법곡동 *-**
#
#        소재지우편번호  WGS84위도  WGS84경도  업태구분명정보           X좌표값           Y좌표값  \
# 0          NaN      NaN      NaN      NaN  245212.733716  480846.133947
# 1      12457.0      NaN      NaN      NaN  233842.021227  466192.802959
# 2          NaN      NaN      NaN      NaN  243247.301370  480064.513852
# 3          NaN      NaN      NaN      NaN  243200.199051  463336.290376
# 4          NaN      NaN      NaN      NaN  236894.589288  470644.366611
# ...        ...      ...      ...      ...            ...            ...
# 14449  18562.0      NaN      NaN      NaN  180335.240868  397423.594307
# 14450  18556.0      NaN      NaN      NaN  175386.850094  407462.012505
# 14451  31560.0      NaN      NaN      NaN  201030.437190  362598.297324
# 14452      NaN      NaN      NaN      NaN  174682.069911  439615.145968
# 14453  31560.0      NaN      NaN      NaN  201030.437190  362598.297324
#
#        축산업무구분명 축산고유번호  권리주체일련번호
# 0       동물관련영업    NaN       000
# 1       동물관련영업    NaN       000
# 2       동물관련영업    0.0       000
# 3       동물관련영업    NaN       000
# 4       동물관련영업    NaN       000
# ...        ...    ...       ...
# 14449   동물관련영업    0.0       000
# 14450   동물관련영업    0.0       000
# 14451   동물관련영업    NaN       000
# 14452   동물관련영업    0.0       000
# 14453      NaN    NaN       NaN
#
# [14454 rows x 21 columns]

# %% [markdown]
# ### 필요한 자료 추려내기 (영업장 위치와 이름 그리고 실제 운영하고 있는 지 여부)

# %%
store_num = store_data[(store_data['영업상태명']) =='정상'].loc[:,['시군명', '사업장명', '소재지지번주소']]
store_num

store_df

town_num = pet.drop_duplicates(['시군명'], keep='first', inplace=False, ignore_index=True)
town = list(town_num['시군명'])
print(town)

ani_list = []
for i in town:
    ani_sum = pet[pet['시군명'].str.contains(i)]['등록동물수(마리)'].sum()
#     ani_list.append([)
#     ani_list.append(ani_sum)
    ani_list.append([i, ani_sum])
print(ani_list)

pet_df = pd.DataFrame(ani_list)
pet_df.columns = ['행정구역명', '총 동물수']
pet_df
# Out:
#        시군명         사업장명                 소재지지번주소
# 56     가평군          러브캣    경기도 가평군 상면 봉수리 **-*
# 57     가평군     가평가족동물학교      경기도 가평군 북면 백둔리 **
# 58     가평군       행복한고양이  경기도 가평군 가평읍 대곡리 ***-*
# 59     가평군           굿독                     NaN
# 60     가평군       유로애견농원    경기도 가평군 설악면 신천리 ***
# ...    ...          ...                     ...
# 14431  화성시          샤르망  경기도 화성시 서신면 용두리 ***-*
# 14432  화성시     오스카코리아켄넬  경기도 화성시 서신면 홍법리 ***-*
# 14433  화성시  Steel Sprit    경기도 화성시 우정읍 멱우리 ***
# 14434  화성시      BLUE&CO  경기도 화성시 장안면 장안리 ***-*
# 14435  화성시    레옹 앤드 사라용  경기도 화성시 송산면 삼존리 ***-*
#
# [976 rows x 3 columns]

# %%
store_num = store_data.loc[:,['시군명','사업장명','영업상태명']]
store = store_num[(store_num['영업상태명'])=='정상']
store
# Out:
#        시군명         사업장명 영업상태명
# 56     가평군          러브캣    정상
# 57     가평군     가평가족동물학교    정상
# 58     가평군       행복한고양이    정상
# 59     가평군           굿독    정상
# 60     가평군       유로애견농원    정상
# ...    ...          ...   ...
# 14431  화성시          샤르망    정상
# 14432  화성시     오스카코리아켄넬    정상
# 14433  화성시  Steel Sprit    정상
# 14434  화성시      BLUE&CO    정상
# 14435  화성시    레옹 앤드 사라용    정상
#
# [976 rows x 3 columns]

# %%
store['시군명'].unique()
# Out:
# array(['가평군', '고양시', '과천시', '광주시', '구리시', '군포시', '김포시', '남양주시', '동두천시',
#        '부천시', '성남시', '수원시', '시흥시', '안산시', '안성시', '안양시', '양주시', '양평군',
#        '여주시', '연천군', '오산시', '용인시', '의왕시', '의정부시', '이천시', '파주시', '평택시',
#        '포천시', '하남시', '화성시'], dtype=object)

# %% [markdown]
# ### 시군별 사업장의 숫자를 파악한다.

# %%
store_count = store.groupby('시군명')
s_count = store_count['사업장명'].count()
s_count
# Out:
# 시군명
# 가평군      22
# 고양시      59
# 과천시       1
# 광주시      33
# 구리시      11
# 군포시       1
# 김포시     111
# 남양주시     41
# 동두천시      7
# 부천시       8
# 성남시       2
# 수원시       7
# 시흥시       8
# 안산시      10
# 안성시      44
# 안양시      17
# 양주시      37
# 양평군      91
# 여주시      56
# 연천군      36
# 오산시       2
# 용인시      42
# 의왕시       2
# 의정부시      4
# 이천시      47
# 파주시     101
# 평택시      38
# 포천시      60
# 하남시       1
# 화성시      77
# Name: 사업장명, dtype: int64

# %%
store_df = pd.DataFrame(s_count)
store_df
# Out:
#       사업장명
# 시군명
# 가평군     22
# 고양시     59
# 과천시      1
# 광주시     33
# 구리시     11
# 군포시      1
# 김포시    111
# 남양주시    41
# 동두천시     7
# 부천시      8
# 성남시      2
# 수원시      7
# 시흥시      8
# 안산시     10
# 안성시     44
# 안양시     17
# 양주시     37
# 양평군     91
# 여주시     56
# 연천군     36
# 오산시      2
# 용인시     42
# 의왕시      2
# 의정부시     4
# 이천시     47
# 파주시    101
# 평택시     38
# 포천시     60
# 하남시      1
# 화성시     77

# %%
stat
# Out:
#       연도 행정구역명    총 인구수   총 동물수
# 12  2022   수원시  1188234   65330
# 1   2022   고양시  1079277   73477
# 22  2022   용인시  1075877   50227
# 11  2022   성남시   928267   55728
# 30  2022   화성시   892038   48264
# 10  2022   부천시   801503  113892
# 8   2022  남양주시   734642   42957
# 14  2022   안산시   650708   86158
# 27  2022   평택시   569369   60468
# 16  2022   안양시   549724   35644
# 13  2022   시흥시   512721   30539
# 26  2022   파주시   486515   24057
# 7   2022   김포시   485609    7912
# 24  2022  의정부시   464358   58997
# 4   2022   광주시   388893   29042
# 29  2022   하남시   323558   17634
# 3   2022   광명시   290756   20161
# 6   2022   군포시   267493   15480
# 17  2022   양주시   236142   54805
# 21  2022   오산시   230028   14471
# 25  2022   이천시   222722   13147
# 5   2022   구리시   191011   12381
# 15  2022   안성시   189772   19950
# 23  2022   의왕시   162137    6590
# 28  2022   포천시   148469   11168
# 18  2022   양평군   121789   13291
# 19  2022   여주시   112410    5252
# 9   2022  동두천시    93260    6998
# 2   2022   과천시    78301    2974
# 0   2022   가평군    62168    4017
# 20  2022   연천군    42731    2020

# %%
# 인구 자료 
pop_data = pd.read_csv('data1/주민등록인구집계현황.csv', encoding='euc-kr')
pop_data
# Out:
#           연도  월 행정구역구분명        행정구역명     총 인구수     0~9세   10~19세   20~29세  \
# 0       2022  9       도        경기도    13574353  1054380  1327378  1753988
# 1       2022  9      시군     경기도 가평군      62168     3047     4471     6009
# 2       2022  9     읍면동  경기도 가평군 가평읍     19532     1062     1677     2125
# 3       2022  9     읍면동   경기도 가평군 북면      3821      126      177      224
# 4       2022  9     읍면동   경기도 가평군 상면      5688      153      244      512
# ...      ... ..     ...          ...       ...      ...      ...      ...
# 107481  2008  1     읍면동  경기도 화성시 팔탄면      9900      869      869     1694
# 107482  2008  1     읍면동  경기도 화성시 향남읍     21100     2828     2288     3151
# 107483  2008  1     읍면동  경기도 화성시 향남읍     21100     2828     2288     3151
# 107484  2008  1     읍면동  경기도 화성시 화산동     23684     3727     2793     3515
# 107485  2008  1     읍면동  경기도 화성시 화산동     23684     3727     2793     3515
#
#          30~39세   40~49세  ...  10~19세 (여)  20~29세 (여)  30~39세 (여)  40~49세 (여)  \
# 0       1880750  2286448  ...      646493      828547      904145     1122988
# 1          5406     7722  ...        2175        2520        2449        3575
# 2          1804     2649  ...         784         959         845        1245
# 3           231      368  ...          90          82          99         164
# 4           389      560  ...         111         155         171         245
# ...         ...      ...  ...         ...         ...         ...         ...
# 107481     1671     1735  ...         407         606         596         717
# 107482     4316     3415  ...        1136        1444        1835        1467
# 107483     4316     3415  ...        1136        1444        1835        1467
# 107484     5424     3869  ...        1296        1699        2528        1737
# 107485     5424     3869  ...        1296        1699        2528        1737
#
#         50~59세 (여)  60~69세 (여)  70~79세 (여)  80~89세 (여)  90~99세 (여)  \
# 0          1131303      864393      435119      248574       43544
# 1             5177        6376        3551        2379         395
# 2             1590        1792        1013         732         117
# 3              309         507         288         206          39
# 4              543         718         384         240          44
# ...            ...         ...         ...         ...         ...
# 107481         579         455         373         120          23
# 107482        1107         797         622         180          34
# 107483        1107         797         622         180          34
# 107484        1079         686         419         115          19
# 107485        1079         686         419         115          19
#
#         100세 이상 (여)
# 0              1373
# 1                15
# 2                 7
# 3                 1
# 4                 0
# ...             ...
# 107481            0
# 107482            4
# 107483            4
# 107484            0
# 107485            0
#
# [107486 rows x 40 columns]

# %%
# 2022년 9월 자료
over_pop = pop_data[(pop_data['연도']==2022) & (pop_data['월']==9) & (pop_data['행정구역구분명']=='시군')]
over_pop
# Out:
#        연도  월 행정구역구분명      행정구역명    총 인구수   0~9세  10~19세  20~29세  30~39세  \
# 1    2022  9      시군   경기도 가평군     62168   3047    4471    6009    5406
# 8    2022  9      시군   경기도 고양시   1079277  76769  101359  144797  142834
# 56   2022  9      시군   경기도 과천시     78301   7252    7477   10114   11678
# 63   2022  9      시군   경기도 광명시    290756  21241   29236   36023   39235
# 83   2022  9      시군   경기도 광주시    388893  32763   34308   44419   55022
# 97   2022  9      시군   경기도 구리시    191011  13565   17140   25407   24761
# 106  2022  9      시군   경기도 군포시    267493  18143   25052   36251   37090
# 119  2022  9      시군   경기도 김포시    485609  52226   50418   51534   73073
# 134  2022  9      시군  경기도 남양주시    734642  61907   78547   85553   89129
# 153  2022  9      시군  경기도 동두천시     93260   5643    8397   10848    9843
# 162  2022  9      시군   경기도 부천시    801503  51652   67213  109471  111137
# 173  2022  9      시군   경기도 성남시    928267  64710   84931  125170  134343
# 228  2022  9      시군   경기도 수원시   1188234  87748  114808  181543  179237
# 277  2022  9      시군   경기도 시흥시    512721  46671   50582   68471   76611
# 297  2022  9      시군   경기도 안산시    650708  40714   60606  103790   85093
# 325  2022  9      시군   경기도 안성시    189772  12831   17799   22908   22614
# 341  2022  9      시군   경기도 안양시    549724  37733   50520   73916   78459
# 376  2022  9      시군   경기도 양주시    236142  19182   24242   27424   27622
# 388  2022  9      시군   경기도 양평군    121789   6937    9676   10446   10606
# 401  2022  9      시군   경기도 여주시    112410   6768    9333   11720   11055
# 414  2022  9      시군   경기도 연천군     42731   2479    2991    5026    4069
# 425  2022  9      시군   경기도 오산시    230028  21083   25011   30730   36694
# 432  2022  9      시군   경기도 용인시   1075877  92224  120364  136510  138616
# 474  2022  9      시군   경기도 의왕시    162137  12341   13903   22121   22633
# 481  2022  9      시군  경기도 의정부시    464358  32355   41486   63633   60029
# 496  2022  9      시군   경기도 이천시    222722  17482   21783   30853   30621
# 511  2022  9      시군   경기도 파주시    486515  42783   50540   59442   68319
# 529  2022  9      시군   경기도 평택시    569369  49711   54447   77697   87007
# 555  2022  9      시군   경기도 포천시    148469   7927   11546   17869   14581
# 571  2022  9      시군   경기도 하남시    323558  32788   29292   37922   53067
# 586  2022  9      시군   경기도 화성시    892038  99321  102360  109222  149583
#
#      40~49세  ...  10~19세 (여)  20~29세 (여)  30~39세 (여)  40~49세 (여)  50~59세 (여)  \
# 1      7722  ...        2175        2520        2449        3575        5177
# 8    175981  ...       49590       70882       71693       90624      100944
# 56    11865  ...        3668        4833        5884        6037        6823
# 63    49324  ...       14175       17320       19193       25074       24582
# 83    68394  ...       16730       20789       26395       32423       32169
# 97    31133  ...        8355       12350       12264       15557       17728
# 106   42096  ...       12094       17369       17597       21308       24232
# 119   93045  ...       24751       25096       37234       44817       34193
# 134  132532  ...       38089       41173       45023       66282       60538
# 153   13662  ...        4162        4986        4686        6626        7799
# 162  124427  ...       32814       53026       53827       61610       74108
# 173  152325  ...       41391       60967       65613       77300       77519
# 228  198380  ...       55573       86323       84688       98572       99549
# 277   92986  ...       24608       31097       35589       42744       42924
# 297  102564  ...       29464       48462       38646       49691       62913
# 325   30177  ...        8527       10256       10193       13997       15070
# 341   85682  ...       24341       35660       38020       43395       49446
# 376   39702  ...       11907       12631       13305       19348       18962
# 388   16376  ...        4615        4645        5173        8092       10200
# 401   15797  ...        4502        5285        5201        7679        9488
# 414    4707  ...        1418        1794        1720        2143        3191
# 425   44294  ...       12150       14084       16606       20670       16367
# 432  196299  ...       58653       65397       69635       99821       85579
# 474   23834  ...        6737       10507       11011       11893       15154
# 481   73273  ...       20227       31541       29277       36330       41556
# 496   35201  ...       10481       13294       14021       16929       17170
# 511   83441  ...       24655       27314       32419       40637       37425
# 529   98547  ...       26430       34310       38811       45701       43712
# 555   19384  ...        5491        7521        6385        8944       13121
# 571   58836  ...       14510       18929       26374       28340       23002
# 586  173706  ...       50219       49864       71040       81620       57825
#
#      60~69세 (여)  70~79세 (여)  80~89세 (여)  90~99세 (여)  100세 이상 (여)
# 1          6376        3551        2379         395           15
# 8         67927       35157       23140        3937          114
# 56         5019        2314        1375         323            9
# 63        20764        9739        5302         899           26
# 83        26827       12073        5872        1070           42
# 97        13257        6438        3334         501           13
# 106       18749        8356        5258         945           39
# 119       27972       14407        7329        1329           35
# 134       47333       25339       13121        2299           94
# 153        7291        4859        3094         448           15
# 162       61436       25829       14100        2579           95
# 173       62189       31771       16685        3218          112
# 228       68725       32549       17985        3192          109
# 277       25870       10991        6695        1210           46
# 297       38855       16651       10473        1873           61
# 325       13823        7541        5150         916           32
# 341       39360       17575        9806        1801           56
# 376       15925        8878        5105         905           26
# 388       12671        6800        4200         835           23
# 401       10049        5361        3659         701           23
# 414        3915        2619        1955         316           10
# 425       11329        5647        2851         455           15
# 432       59634       36706       18231        3323          121
# 474       11940        4881        2914         587           22
# 481       32353       17605        9811        1539           43
# 496       14165        7173        4600         787           23
# 511       28175       16169       10034        1767           56
# 529       30966       16238        9891        1563           58
# 555       12555        6520        4545         770           24
# 571       20442        9035        4217         895           39
# 586       39053       18089       10204        1872           47
#
# [31 rows x 40 columns]

# %%
pop = over_pop.loc[:, ['연도','행정구역명','총 인구수']]
pop['행정구역명'] = ['가평군', '고양시', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시', '남양주시', 
'동두천시', '부천시', '성남시', '수원시', '시흥시', '안산시', '안성시', '안양시', '양주시', '양평군', '여주시', '연천군', 
'오산시', '용인시', '의왕시', '의정부시', '이천시', '파주시', '평택시', '포천시', '하남시', '화성시']
pop
# Out:
#        연도 행정구역명    총 인구수
# 1    2022   가평군    62168
# 8    2022   고양시  1079277
# 56   2022   과천시    78301
# 63   2022   광명시   290756
# 83   2022   광주시   388893
# 97   2022   구리시   191011
# 106  2022   군포시   267493
# 119  2022   김포시   485609
# 134  2022  남양주시   734642
# 153  2022  동두천시    93260
# 162  2022   부천시   801503
# 173  2022   성남시   928267
# 228  2022   수원시  1188234
# 277  2022   시흥시   512721
# 297  2022   안산시   650708
# 325  2022   안성시   189772
# 341  2022   안양시   549724
# 376  2022   양주시   236142
# 388  2022   양평군   121789
# 401  2022   여주시   112410
# 414  2022   연천군    42731
# 425  2022   오산시   230028
# 432  2022   용인시  1075877
# 474  2022   의왕시   162137
# 481  2022  의정부시   464358
# 496  2022   이천시   222722
# 511  2022   파주시   486515
# 529  2022   평택시   569369
# 555  2022   포천시   148469
# 571  2022   하남시   323558
# 586  2022   화성시   892038

# %%
# 동물 통계

# %%
# 데이터 기준 일자 2022-06-14
pet_data = pd.read_csv('data1/반려동물등록현황.csv', encoding='euc-kr')
pet_data
# Out:
#      시군명 읍면동명  등록동물수(마리)  (등록주체)시군구등록  (등록주체)대행업체등록  (등록주체)기타  (RFID종류)내장형  \
# 0    가평군  가평읍        941          NaN           NaN       NaN          596
# 1    가평군   북면        289          NaN           NaN       NaN          176
# 2    가평군   상면        399          NaN           NaN       NaN          217
# 3    가평군  설악면       1111          NaN           NaN       NaN          446
# 4    가평군  조종면        416          NaN           NaN       NaN          218
# ..   ...  ...        ...          ...           ...       ...          ...
# 724  화성시  청계동       2046         90.0        1956.0       0.0         1052
# 725  화성시  팔탄면        753         87.0         665.0       1.0          345
# 726  화성시  향남읍       5180        314.0        4863.0       3.0         2110
# 727  화성시  활초동         15          0.0          15.0       0.0            4
# 728  화성시  황계동         52         16.0          36.0       0.0           19
#
#      (RFID종류)외장형  (RFID종류)인식표  등록품종수  등록소유자수  동물소유자당등록동물수  해당동의등록대행업체수  \
# 0            294           51    NaN    85.0          NaN          3.0
# 1             93           20    NaN   185.0          NaN          0.0
# 2            153           29    NaN   243.0          NaN          0.0
# 3            612           53    NaN   625.0          NaN          1.0
# 4            161           37    NaN   274.0          NaN          1.0
# ..           ...          ...    ...     ...          ...          ...
# 724          879          115   66.0  1679.0         1.22          4.0
# 725          305          103   62.0   412.0         1.83          1.0
# 726         2584          486  103.0  3719.0         1.39          6.0
# 727           11            0    7.0    11.0         1.36          0.0
# 728           13           20   15.0    24.0         2.17          0.0
#
#         데이터기준일자
# 0    2022-06-14
# 1    2022-06-14
# 2    2022-06-14
# 3    2022-06-14
# 4    2022-06-14
# ..          ...
# 724  2022-05-31
# 725  2022-05-31
# 726  2022-05-31
# 727  2022-05-31
# 728  2022-05-31
#
# [729 rows x 14 columns]

# %%
pet = pet_data.loc[:,['시군명','읍면동명','등록동물수(마리)','등록소유자수','해당동의등록대행업체수']]
pet
# Out:
#      시군명 읍면동명  등록동물수(마리)  등록소유자수  해당동의등록대행업체수
# 0    가평군  가평읍        941    85.0          3.0
# 1    가평군   북면        289   185.0          0.0
# 2    가평군   상면        399   243.0          0.0
# 3    가평군  설악면       1111   625.0          1.0
# 4    가평군  조종면        416   274.0          1.0
# ..   ...  ...        ...     ...          ...
# 724  화성시  청계동       2046  1679.0          4.0
# 725  화성시  팔탄면        753   412.0          1.0
# 726  화성시  향남읍       5180  3719.0          6.0
# 727  화성시  활초동         15    11.0          0.0
# 728  화성시  황계동         52    24.0          0.0
#
# [729 rows x 5 columns]

# %%
town_num = pet.drop_duplicates(['시군명'], keep='first', inplace=False, ignore_index=True)
town = list(town_num['시군명'])
town
print(len(town))
# Out:
# ['가평군',
#  '고양시',
#  '과천시',
#  '광명시',
#  '광주시',
#  '구리시',
#  '군포시',
#  '김포시',
#  '남양주시',
#  '동두천시',
#  '부천시',
#  '성남시',
#  '수원시',
#  '시흥시',
#  '안산시',
#  '안성시',
#  '안양시',
#  '양주시',
#  '양평군',
#  '여주시',
#  '연천군',
#  '오산시',
#  '용인시',
#  '의왕시',
#  '의정부시',
#  '이천시',
#  '파주시',
#  '평택시',
#  '포천시',
#  '하남시',
#  '화성시']

# %%
ani_list = []
for i in town:
    ani_sum = pet[pet['시군명'].str.contains(i)]['등록동물수(마리)'].sum()
#     ani_list.append([)
#     ani_list.append(ani_sum)
    ani_list.append([i, ani_sum])
print(ani_list)
# Out:
# [['가평군', 4017], ['고양시', 73477], ['과천시', 2974], ['광명시', 20161], ['광주시', 29042], ['구리시', 12381], ['군포시', 15480], ['김포시', 7912], ['남양주시', 42957], ['동두천시', 6998], ['부천시', 113892], ['성남시', 55728], ['수원시', 65330], ['시흥시', 30539], ['안산시', 86158], ['안성시', 19950], ['안양시', 35644], ['양주시', 54805], ['양평군', 13291], ['여주시', 5252], ['연천군', 2020], ['오산시', 14471], ['용인시', 50227], ['의왕시', 6590], ['의정부시', 58997], ['이천시', 13147], ['파주시', 24057], ['평택시', 60468], ['포천시', 11168], ['하남시', 17634], ['화성시', 48264]]

# %%
ani_df = pd.DataFrame(ani_list)
ani_df.columns = ['행정구역명', '총 동물수']
ani_df
# Out:
#    행정구역명   총 동물수
# 0    가평군    4017
# 1    고양시   73477
# 2    과천시    2974
# 3    광명시   20161
# 4    광주시   29042
# 5    구리시   12381
# 6    군포시   15480
# 7    김포시    7912
# 8   남양주시   42957
# 9   동두천시    6998
# 10   부천시  113892
# 11   성남시   55728
# 12   수원시   65330
# 13   시흥시   30539
# 14   안산시   86158
# 15   안성시   19950
# 16   안양시   35644
# 17   양주시   54805
# 18   양평군   13291
# 19   여주시    5252
# 20   연천군    2020
# 21   오산시   14471
# 22   용인시   50227
# 23   의왕시    6590
# 24  의정부시   58997
# 25   이천시   13147
# 26   파주시   24057
# 27   평택시   60468
# 28   포천시   11168
# 29   하남시   17634
# 30   화성시   48264

# %%
# 자료 합치기

# %%
stat1 = pd.merge(pop, ani_df, how="outer")
stat1
# Out:
#       연도 행정구역명    총 인구수   총 동물수
# 0   2022   가평군    62168    4017
# 1   2022   고양시  1079277   73477
# 2   2022   과천시    78301    2974
# 3   2022   광명시   290756   20161
# 4   2022   광주시   388893   29042
# 5   2022   구리시   191011   12381
# 6   2022   군포시   267493   15480
# 7   2022   김포시   485609    7912
# 8   2022  남양주시   734642   42957
# 9   2022  동두천시    93260    6998
# 10  2022   부천시   801503  113892
# 11  2022   성남시   928267   55728
# 12  2022   수원시  1188234   65330
# 13  2022   시흥시   512721   30539
# 14  2022   안산시   650708   86158
# 15  2022   안성시   189772   19950
# 16  2022   안양시   549724   35644
# 17  2022   양주시   236142   54805
# 18  2022   양평군   121789   13291
# 19  2022   여주시   112410    5252
# 20  2022   연천군    42731    2020
# 21  2022   오산시   230028   14471
# 22  2022   용인시  1075877   50227
# 23  2022   의왕시   162137    6590
# 24  2022  의정부시   464358   58997
# 25  2022   이천시   222722   13147
# 26  2022   파주시   486515   24057
# 27  2022   평택시   569369   60468
# 28  2022   포천시   148469   11168
# 29  2022   하남시   323558   17634
# 30  2022   화성시   892038   48264

# %%
stat1.sort_values(by=['총 인구수','총 동물수'],ascending=False)
# Out:
#       연도 행정구역명    총 인구수   총 동물수
# 12  2022   수원시  1188234   65330
# 1   2022   고양시  1079277   73477
# 22  2022   용인시  1075877   50227
# 11  2022   성남시   928267   55728
# 30  2022   화성시   892038   48264
# 10  2022   부천시   801503  113892
# 8   2022  남양주시   734642   42957
# 14  2022   안산시   650708   86158
# 27  2022   평택시   569369   60468
# 16  2022   안양시   549724   35644
# 13  2022   시흥시   512721   30539
# 26  2022   파주시   486515   24057
# 7   2022   김포시   485609    7912
# 24  2022  의정부시   464358   58997
# 4   2022   광주시   388893   29042
# 29  2022   하남시   323558   17634
# 3   2022   광명시   290756   20161
# 6   2022   군포시   267493   15480
# 17  2022   양주시   236142   54805
# 21  2022   오산시   230028   14471
# 25  2022   이천시   222722   13147
# 5   2022   구리시   191011   12381
# 15  2022   안성시   189772   19950
# 23  2022   의왕시   162137    6590
# 28  2022   포천시   148469   11168
# 18  2022   양평군   121789   13291
# 19  2022   여주시   112410    5252
# 9   2022  동두천시    93260    6998
# 2   2022   과천시    78301    2974
# 0   2022   가평군    62168    4017
# 20  2022   연천군    42731    2020

# %%
# 반려동물 관련 업체

# %%
pet_store = pd.read_csv('data1/반려동물판매업체현황.csv',encoding='cp949')
pet_store
# Out:
#        시군명               사업장명     인허가일자  인허가취소일자  영업상태구분코드 영업상태명        폐업일자  \
# 0      가평군              예쁜강아지  20080909      NaN         4    말소  20220526.0
# 1      가평군             자이언트 펫  20160517      NaN         4    말소  20220526.0
# 2      가평군              메이플켄넬  20170227      NaN         4    말소         NaN
# 3      가평군               리얼펫독  20150120      NaN         4    말소  20220526.0
# 4      가평군              강아지나라  20100311      NaN         4    말소  20220526.0
# ...    ...                ...       ...      ...       ...   ...         ...
# 14449  화성시             금은이네농장  20211119      NaN         2    폐업  20220728.0
# 14450  화성시             냥이와 양이  20170530      NaN         1    휴업         NaN
# 14451  NaN  학교종이 댕댕댕(24거3849)  20200909      NaN         4    말소  20220526.0
# 14452  NaN               쁘띠살롱  20220126      NaN         4    말소  20220526.0
# 14453  NaN  학교종이 댕댕댕(24거3849)  20200909      NaN         4    말소  20220701.0
#
#           소재지시설전화번호  소재지면적정보  도로명우편번호  ...                    소재지지번주소  \
# 0               NaN      NaN      NaN  ...   경기도 가평군 가평읍 읍내리 ***-*번지
# 1      031-585-7003      0.0  12457.0  ...  경기도 가평군 청평면 대성리 ***-**번지
# 2          585-0588      0.0  12416.0  ...     경기도 가평군 가평읍 대곡리 ***-*
# 3               NaN      0.0  12467.0  ...     경기도 가평군 설악면 신천리 ***-*
# 4               NaN      NaN      NaN  ...  경기도 가평군 청평면 청평리 ***-**번지
# ...             ...      ...      ...  ...                        ...
# 14449           NaN      0.0  18562.0  ...       경기도 화성시 우정읍 운평리 ***
# 14450           NaN      0.0  18556.0  ...     경기도 화성시 서신면 홍법리 ***-*
# 14451           NaN      0.0  31560.0  ...         충청남도 아산시 법곡동 *-**
# 14452           NaN      0.0  21548.0  ...       인천광역시 남동구 구월동 **-**
# 14453           NaN      0.0  31560.0  ...         충청남도 아산시 법곡동 *-**
#
#        소재지우편번호  WGS84위도  WGS84경도  업태구분명정보           X좌표값           Y좌표값  \
# 0          NaN      NaN      NaN      NaN  245212.733716  480846.133947
# 1      12457.0      NaN      NaN      NaN  233842.021227  466192.802959
# 2          NaN      NaN      NaN      NaN  243247.301370  480064.513852
# 3          NaN      NaN      NaN      NaN  243200.199051  463336.290376
# 4          NaN      NaN      NaN      NaN  236894.589288  470644.366611
# ...        ...      ...      ...      ...            ...            ...
# 14449  18562.0      NaN      NaN      NaN  180335.240868  397423.594307
# 14450  18556.0      NaN      NaN      NaN  175386.850094  407462.012505
# 14451  31560.0      NaN      NaN      NaN  201030.437190  362598.297324
# 14452      NaN      NaN      NaN      NaN  174682.069911  439615.145968
# 14453  31560.0      NaN      NaN      NaN  201030.437190  362598.297324
#
#        축산업무구분명 축산고유번호  권리주체일련번호
# 0       동물관련영업    NaN       000
# 1       동물관련영업    NaN       000
# 2       동물관련영업    0.0       000
# 3       동물관련영업    NaN       000
# 4       동물관련영업    NaN       000
# ...        ...    ...       ...
# 14449   동물관련영업    0.0       000
# 14450   동물관련영업    0.0       000
# 14451   동물관련영업    NaN       000
# 14452   동물관련영업    0.0       000
# 14453      NaN    NaN       NaN
#
# [14454 rows x 21 columns]

# %%
store_num = pet_store[(pet_store['영업상태명']) =='정상'].loc[:,['시군명', '사업장명', '소재지지번주소']]
store_num

store_df

town_num = pet.drop_duplicates(['시군명'], keep='first', inplace=False, ignore_index=True)
town = list(town_num['시군명'])
print(town)

ani_list = []
for i in town:
    ani_sum = pet[pet['시군명'].str.contains(i)]['등록동물수(마리)'].sum()
#     ani_list.append([)
#     ani_list.append(ani_sum)
    ani_list.append([i, ani_sum])
print(ani_list)

pet_df = pd.DataFrame(ani_list)
pet_df.columns = ['행정구역명', '총 동물수']
pet_df
# Out:
#        시군명         사업장명                 소재지지번주소
# 56     가평군          러브캣    경기도 가평군 상면 봉수리 **-*
# 57     가평군     가평가족동물학교      경기도 가평군 북면 백둔리 **
# 58     가평군       행복한고양이  경기도 가평군 가평읍 대곡리 ***-*
# 59     가평군           굿독                     NaN
# 60     가평군       유로애견농원    경기도 가평군 설악면 신천리 ***
# ...    ...          ...                     ...
# 14431  화성시          샤르망  경기도 화성시 서신면 용두리 ***-*
# 14432  화성시     오스카코리아켄넬  경기도 화성시 서신면 홍법리 ***-*
# 14433  화성시  Steel Sprit    경기도 화성시 우정읍 멱우리 ***
# 14434  화성시      BLUE&CO  경기도 화성시 장안면 장안리 ***-*
# 14435  화성시    레옹 앤드 사라용  경기도 화성시 송산면 삼존리 ***-*
#
# [976 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [154], in <cell line: 2>()
#       1 store = store_num.drop_duplicates(['시군명'], keep='first', inplace=False, ignore_index=True)
# ----> 2 shop = list(store['시군명'].count())
#       3 shop
#
# TypeError: 'numpy.int64' object is not iterable

# %%
shop_df = pd.DataFrame(shop)
shop_df.columns = ['행정구역명']
shop_df
# Out:
#    행정구역명
# 0    가평군
# 1    고양시
# 2    과천시
# 3    광주시
# 4    구리시
# 5    군포시
# 6    김포시
# 7   남양주시
# 8   동두천시
# 9    부천시
# 10   성남시
# 11   수원시
# 12   시흥시
# 13   안산시
# 14   안성시
# 15   안양시
# 16   양주시
# 17   양평군
# 18   여주시
# 19   연천군
# 20   오산시
# 21   용인시
# 22   의왕시
# 23  의정부시
# 24   이천시
# 25   파주시
# 26   평택시
# 27   포천시
# 28   하남시
# 29   화성시

# %%
stat = pd.merge(stat1, shop_df, how="outer")
stat
# Out:
#       연도 행정구역명    총 인구수   총 동물수
# 0   2022   가평군    62168    4017
# 1   2022   고양시  1079277   73477
# 2   2022   과천시    78301    2974
# 3   2022   광명시   290756   20161
# 4   2022   광주시   388893   29042
# 5   2022   구리시   191011   12381
# 6   2022   군포시   267493   15480
# 7   2022   김포시   485609    7912
# 8   2022  남양주시   734642   42957
# 9   2022  동두천시    93260    6998
# 10  2022   부천시   801503  113892
# 11  2022   성남시   928267   55728
# 12  2022   수원시  1188234   65330
# 13  2022   시흥시   512721   30539
# 14  2022   안산시   650708   86158
# 15  2022   안성시   189772   19950
# 16  2022   안양시   549724   35644
# 17  2022   양주시   236142   54805
# 18  2022   양평군   121789   13291
# 19  2022   여주시   112410    5252
# 20  2022   연천군    42731    2020
# 21  2022   오산시   230028   14471
# 22  2022   용인시  1075877   50227
# 23  2022   의왕시   162137    6590
# 24  2022  의정부시   464358   58997
# 25  2022   이천시   222722   13147
# 26  2022   파주시   486515   24057
# 27  2022   평택시   569369   60468
# 28  2022   포천시   148469   11168
# 29  2022   하남시   323558   17634
# 30  2022   화성시   892038   48264
