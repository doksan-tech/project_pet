# %%
import numpy as np
import pandas as pd
import folium
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pet = pd.read_csv('반려동물등록현황.csv', encoding='euc-kr')
pet
# Out:
#      시군명 읍면동명  등록동물수(마리)  (등록주체)시군구등록  (등록주체)대행업체등록  (등록주체)기타  (RFID종류)내장형  \
# 0    가평군  가평읍        941          NaN           NaN       NaN          596
# 1    가평군   북면        289          NaN           NaN       NaN          176
# 2    가평군   상면        399          NaN           NaN       NaN          217
# 3    가평군  설악면       1111          NaN           NaN       NaN          446
# 4    가평군  조종면        416          NaN           NaN       NaN          218
# ..   ...  ...        ...          ...           ...       ...          ...
# 724  화성시  청계동       2046         90.0        1956.0       0.0         1052
# 725  화성시  팔탄면        753         87.0         665.0       1.0          345
# 726  화성시  향남읍       5180        314.0        4863.0       3.0         2110
# 727  화성시  활초동         15          0.0          15.0       0.0            4
# 728  화성시  황계동         52         16.0          36.0       0.0           19
#
# ...

# %%
pet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   시군명           729 non-null    object
#  1   읍면동명          727 non-null    object
#  2   등록동물수(마리)     729 non-null    int64
#  3   (등록주체)시군구등록   723 non-null    float64
#  4   (등록주체)대행업체등록  723 non-null    float64
#  5   (등록주체)기타      712 non-null    float64
#  6   (RFID종류)내장형   729 non-null    int64
#  7   (RFID종류)외장형   729 non-null    int64
#  8   (RFID종류)인식표   729 non-null    int64
#  9   등록품종수         723 non-null    float64
#  10  등록소유자수        728 non-null    float64
#  11  동물소유자당등록동물수   722 non-null    float64
#  12  해당동의등록대행업체수   420 non-null    float64
#  13  데이터기준일자       729 non-null    object
# dtypes: float64(7), int64(4), object(3)
# memory usage: 79.9+ KB

# %% [markdown]
# ## 필요한 컬럼 선택

# %%
pet.columns
# Out:
# Index(['시군명', '읍면동명', '등록동물수(마리)', '(등록주체)시군구등록', '(등록주체)대행업체등록', '(등록주체)기타',
#        '(RFID종류)내장형', '(RFID종류)외장형', '(RFID종류)인식표', '등록품종수', '등록소유자수',
#        '동물소유자당등록동물수', '해당동의등록대행업체수', '데이터기준일자'],
#       dtype='object')

# %%
pet = pet.loc[:, ['시군명', '읍면동명', '등록동물수(마리)', '등록소유자수']]
pet
# Out:
#      시군명 읍면동명  등록동물수(마리)  등록소유자수
# 0    가평군  가평읍        941    85.0
# 1    가평군   북면        289   185.0
# 2    가평군   상면        399   243.0
# 3    가평군  설악면       1111   625.0
# 4    가평군  조종면        416   274.0
# ..   ...  ...        ...     ...
# 724  화성시  청계동       2046  1679.0
# 725  화성시  팔탄면        753   412.0
# 726  화성시  향남읍       5180  3719.0
# 727  화성시  활초동         15    11.0
# 728  화성시  황계동         52    24.0
#
# [729 rows x 4 columns]

# %% [markdown]
# ## 결측치 확인

# %%
pet.isna().sum()
# Out:
# 시군명               0
# 읍면동명              2
# 등록동물수(마리)         0
# (등록주체)시군구등록       6
# (등록주체)대행업체등록      6
# (등록주체)기타         17
# (RFID종류)내장형       0
# (RFID종류)외장형       0
# (RFID종류)인식표       0
# 등록품종수             6
# 등록소유자수            1
# 동물소유자당등록동물수       7
# 해당동의등록대행업체수     309
# 데이터기준일자           0
# dtype: int64

# %% [markdown]
# ## 행정명 확인

# %%
pet['시군명'].unique(), len(pet['시군명'].unique())
# Out:
# (array(['가평군', '고양시', '과천시', '광명시', '광주시', '구리시', '군포시', '김포시', '남양주시',
#         '동두천시', '부천시', '성남시', '수원시', '시흥시', '안산시', '안성시', '안양시', '양주시',
#         '양평군', '여주시', '연천군', '오산시', '용인시', '의왕시', '의정부시', '이천시', '파주시',
#         '평택시', '포천시', '하남시', '화성시'], dtype=object),
#  31)

# %%
pet['읍면동명'].unique(), len(pet['읍면동명'].unique())
# Out:
# (array(['가평읍', '북면', '상면', '설악면', '조종면', '청평면', '가좌동', '강매동', '고양동', '관산동',
#         '구산동', '내곡동', '내유동', '대자동', '대장동', '대화동', '덕은동', '덕이동', '도내동',
#         '동산동', '마두동', '문봉동', '백석동', '법곳동', '벽제동', '북한동', '사리현동', '산황동',
#         '삼송동', '선유동', '설문동', '성사동', '성석동', '식사동', '신원동', '신평동', '오금동',
#         '용두동', '원당동', '원흥동', '일산동', '장항동', '정발산동', '주교동', '주엽동', '중산동',
#         '지영동', '지축동', '탄현동', '토당동', '풍동', '행신동', '행주내동', '행주외동', '향동동',
#         '현천동', '화전동', '화정동', '효자동', '갈현동', '과천동', '관문동', '막계동', '문원동',
#         '별양동', '부림동', '원문동', '주암동', '중앙동', '가학동', '광명동', '노온사동', '소하동',
#         '옥길동', '일직동', '철산동', '하안동', '경안동', '곤지암읍', '남종면', '남한산성면', '도척면',
#         '목동', '목현동', '삼동', '송정동', '실촌읍', '쌍령동', '역동', '오포읍', '장지동', '중대동',
#         '중부면', '직동', '초월읍', '탄벌동', '태전동', '퇴촌면', '회덕동', '갈매동', '교문동',
#         '사노동', '수택동', '아천동', '인창동', '토평동', nan, '감정동', '걸포동', '고촌읍', '구래동',
#         '대곶면', '마산동', '북변동', '사우동', '양촌읍', '운양동', '월곶면', '장기동', '통진읍',
# ...
