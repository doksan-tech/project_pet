# %%
import numpy as np
import pandas as pd

# %%
store = pd.read_csv('data/반려동물판매업체현황.csv', encoding='cp949')
store
# Out:
#        시군명               사업장명     인허가일자  인허가취소일자  영업상태구분코드 영업상태명        폐업일자  \
# 0      가평군              예쁜강아지  20080909      NaN         4    말소  20220526.0
# 1      가평군             자이언트 펫  20160517      NaN         4    말소  20220526.0
# 2      가평군              메이플켄넬  20170227      NaN         4    말소         NaN
# 3      가평군               리얼펫독  20150120      NaN         4    말소  20220526.0
# 4      가평군              강아지나라  20100311      NaN         4    말소  20220526.0
# ...    ...                ...       ...      ...       ...   ...         ...
# 14449  화성시             금은이네농장  20211119      NaN         2    폐업  20220728.0
# 14450  화성시             냥이와 양이  20170530      NaN         1    휴업         NaN
# 14451  NaN  학교종이 댕댕댕(24거3849)  20200909      NaN         4    말소  20220526.0
# 14452  NaN               쁘띠살롱  20220126      NaN         4    말소  20220526.0
# 14453  NaN  학교종이 댕댕댕(24거3849)  20200909      NaN         4    말소  20220701.0
#
# ...

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14454 entries, 0 to 14453
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시군명        14451 non-null  object
#  1   사업장명       14454 non-null  object
#  2   인허가일자      14454 non-null  int64
#  3   인허가취소일자    0 non-null      float64
#  4   영업상태구분코드   14454 non-null  int64
#  5   영업상태명      14454 non-null  object
#  6   폐업일자       13427 non-null  float64
#  7   소재지시설전화번호  6062 non-null   object
#  8   소재지면적정보    13709 non-null  float64
#  9   도로명우편번호    13541 non-null  float64
#  10  소재지도로명주소   14078 non-null  object
#  11  소재지지번주소    14124 non-null  object
#  12  소재지우편번호    1803 non-null   float64
#  13  WGS84위도    4 non-null      float64
#  14  WGS84경도    4 non-null      float64
#  15  업태구분명정보    0 non-null      float64
#  16  X좌표값       13691 non-null  float64
#  17  Y좌표값       13691 non-null  float64
#  18  축산업무구분명    13998 non-null  object
# ...

# %%
city1 = (store['시군명'] == '고양시')
store[city1]
# Out:
#      시군명      사업장명     인허가일자  인허가취소일자  영업상태구분코드 영업상태명        폐업일자  \
# 83   고양시   애기야목욕가자  20180521      NaN         4    말소  20220526.0
# 84   고양시     제이제이펫  20120207      NaN         4    말소  20220526.0
# 85   고양시     리사앤루이  20170227      NaN         4    말소  20220526.0
# 86   고양시        탑독  20090327      NaN         4    말소  20220526.0
# 87   고양시     캣브리더스  20140103      NaN         4    말소  20220526.0
# ..   ...       ...       ...      ...       ...   ...         ...
# 849  고양시       정글펫  20211103      NaN         2    폐업  20220901.0
# 850  고양시  원흥동물의료센터  20181008      NaN         2    폐업  20220729.0
# 851  고양시   가람 동물병원  20090414      NaN         2    폐업  20220829.0
# 852  고양시    Catdog  20200110      NaN         2    폐업  20220919.0
# 853  고양시  토론토 동물병원  20100819      NaN         2    폐업  20220922.0
#
#         소재지시설전화번호  소재지면적정보  도로명우편번호  ...                              소재지지번주소  \
# 83    02-381-7542      0.0  10568.0  ...        경기도 고양시 덕양구 신원동 ***번지 유창 프라자
# ...

# %%
open = (store['영업상태명'] == '정상')
store[open]
# Out:
#        시군명         사업장명     인허가일자  인허가취소일자  영업상태구분코드 영업상태명  폐업일자 소재지시설전화번호  \
# 56     가평군          러브캣  20181106      NaN         0    정상   NaN       NaN
# 57     가평군     가평가족동물학교  20180622      NaN         0    정상   NaN       NaN
# 58     가평군       행복한고양이  20180518      NaN         0    정상   NaN       NaN
# 59     가평군           굿독  20170227      NaN         0    정상   NaN       NaN
# 60     가평군       유로애견농원  20190412      NaN         0    정상   NaN       NaN
# ...    ...          ...       ...      ...       ...   ...   ...       ...
# 14431  화성시          샤르망  20170126      NaN         0    정상   NaN       NaN
# 14432  화성시     오스카코리아켄넬  20211206      NaN         0    정상   NaN       NaN
# 14433  화성시  Steel Sprit  20211207      NaN         0    정상   NaN       NaN
# 14434  화성시      BLUE&CO  20211119      NaN         0    정상   NaN       NaN
# 14435  화성시    레옹 앤드 사라용  20170831      NaN         0    정상   NaN       NaN
#
# ...

# %% [markdown]
# ### 고양시 영업중인 동물병원만 확인

# %%
city1 = store[(store['영업상태명'] == '정상') & (store['시군명'] == '고양시')]
city1
# Out:
#      시군명                           사업장명     인허가일자  인허가취소일자  영업상태구분코드 영업상태명  \
# 772  고양시                        AHA(아하)  20220706      NaN         0    정상
# 773  고양시                          그루머연우  20220920      NaN         0    정상
# 774  고양시                         오엠동물병원  20220802      NaN         0    정상
# 775  고양시                    pet 33두1367  20220802      NaN         0    정상
# 776  고양시                    pet196저6204  20220805      NaN         0    정상
# 777  고양시                    pet338주5091  20220817      NaN         0    정상
# 778  고양시                         해랑동물병원  20220901      NaN         0    정상
# 779  고양시                   일산 강아지고양이 캣독  20220927      NaN         0    정상
# 780  고양시                           더도그홈  20221007      NaN         0    정상
# 781  고양시                           더도그홈  20221007      NaN         0    정상
# 782  고양시                   일산 강아지고양이 캣독  20220919      NaN         0    정상
# ...

# %%
shop = pd.read_csv('data/병원위도경도.csv', encoding='utf-8')
shop
# Out:
#       시군명                  사업장명 영업상태명    WGS84위도     WGS84경도
# 0     가평군           가평축산농협 동물병원    정상  37.824454  127.514711
# 1     가평군  우랑동물병원(산업동물출장진료전문병원)    정상  37.833123  127.508921
# 2     가평군                경기동물병원    정상  37.735775  127.415869
# 3     가평군                설악동물병원    정상  37.677775  127.490385
# 4     가평군                현리동물병원    정상  37.820426  127.346423
# ...   ...                   ...   ...        ...         ...
# 1261  화성시            누리팜 산업동물병원    정상  37.032462  126.853184
# 1262  화성시              힐링동물의료센터    정상  37.236313  127.061388
# 1263  화성시             쥬만지동물의료센터    정상  37.202716  127.123719
# 1264  화성시               S동물의료센터    정상  37.208818  127.063147
# 1265  화성시          스마트동물병원(병점점)    정상  37.213600  127.040432
#
# [1266 rows x 5 columns]

# %%
goyang = shop[(shop['영업상태명'] == '정상') & (shop['시군명'] == '고양시')]
goyang
# Out:
#      시군명        사업장명 영업상태명    WGS84위도     WGS84경도
# 9    고양시  Dr.JK 동물병원    정상  37.662193  126.766412
# 10   고양시      고양동물병원    정상  37.701076  126.901824
# 11   고양시     스마트동물병원    정상  37.661740  126.764770
# 12   고양시      경서동물병원    정상  37.600696  126.872837
# 13   고양시     신일산동물병원    정상  37.654739  126.783626
# ..   ...         ...   ...        ...         ...
# 121  고양시    벳케어 동물병원    정상  37.687073  126.719193
# 122  고양시    반딧불 동물병원    정상  37.670324  126.759687
# 123  고양시    김 S 동물병원    정상  37.666658  126.773595
# 124  고양시      예 동물병원    정상  37.630298  126.869421
# 125  고양시  24일산우리동물병원    정상  37.670897  126.758523
#
# [117 rows x 5 columns]

# %%
goyang.to_csv('goyang.csv', encoding='utf-8')

# %%
goyang = pd.read_csv('goyang.csv')
goyang
# Out:
#      Unnamed: 0  시군명        사업장명 영업상태명    WGS84위도     WGS84경도
# 0             9  고양시  Dr.JK 동물병원    정상  37.662193  126.766412
# 1            10  고양시      고양동물병원    정상  37.701076  126.901824
# 2            11  고양시     스마트동물병원    정상  37.661740  126.764770
# 3            12  고양시      경서동물병원    정상  37.600696  126.872837
# 4            13  고양시     신일산동물병원    정상  37.654739  126.783626
# ..          ...  ...         ...   ...        ...         ...
# 112         121  고양시    벳케어 동물병원    정상  37.687073  126.719193
# 113         122  고양시    반딧불 동물병원    정상  37.670324  126.759687
# 114         123  고양시    김 S 동물병원    정상  37.666658  126.773595
# 115         124  고양시      예 동물병원    정상  37.630298  126.869421
# 116         125  고양시  24일산우리동물병원    정상  37.670897  126.758523
#
# [117 rows x 6 columns]

# %% [markdown]
# ### 병원명 리스트 만들기

# %%
df_dict = goyang.to_dict()
dic_val = df_dict['사업장명'].values()
shop_list = list(dic_val)

# %%
shop_list
# Out:
# ['Dr.JK 동물병원',
#  '고양동물병원',
#  '스마트동물병원',
#  '경서동물병원',
#  '신일산동물병원',
#  '더독',
#  '탑케어동물의료원',
#  '고양 우리아이 동물병원',
#  '조이동물병원',
#  '펫피아 동물병원',
#  '제이엠 동물병원',
#  '오엠동물병원',
#  '풍동동물병원',
#  '행신동물병원',
#  '마리동물병원',
#  '풍동 라파엘 동물병원',
#  '워리워리',
#  'Helix ADI Center : 헬릭스 영상진단센터',
#  '그랜드 동물병원',
#  '24시 나음동물의료센터',
#  '웰니스동물병원 스타필드 고양',
#  '원흥동물의료센터',
#  '해밀동물병원',
#  '탑동물병원',
#  '민동물병원',
#  '화정동물병원',
#  '헬릭스동물메디컬센터',
#  '아이편한 동물의료센터',
#  'Dr. dog 동물영상의료센터',
#  '쿨펫동물병원 킨텍스점',
#  '위시티 동물병원',
#  '수 동물병원',
#  '에드워드동물병원',
#  '해랑동물병원',
#  '펫스티벌 동물병원',
#  '조이동물병원 제니스점',
#  '시민종합동물병원',
#  '펫스마일동물병원',
#  '현대동물병원',
#  '펫앤유 24시 동물병원',
#  '경서동물병원',
#  '해오름 동물병원',
#  'FM 동물메디컬센터',
#  '삼송동물병원',
#  '고양시 동물보호센터',
#  '삼송사랑 동물의료센터',
#  '더바름동물병원',
#  '쥬박스동물병원(탑동물병원)',
#  '닥터서동물심장병원',
#  '중산동물메디컬센터',
#  '소노펫 동물병원',
#  '새로이동물병원',
#  '서울하은동물병원',
#  '위즈펫동물병원 풍산점',
#  '하노버',
#  '호수동물병원',
#  '작은 친구 동물병원',
#  '삼송동물의료센터',
#  '일산동물의료원',
#  '원당동물병원',
#  '해맑은 동물병원',
#  '사과나무 동물병원',
#  '포근한동물병원',
#  '참사랑',
#  '자유로 동물병원',
# ...

# %%
names = shop_list

# %% [markdown]
# ### 위도 리스트 만들기

# %%
df_dict = goyang.to_dict()
dic_val = df_dict['WGS84위도'].values()
latitude = list(dic_val)

# %%
latitude
# Out:
# [37.6621933,
#  37.7010764859,
#  37.6617395,
#  37.6006961,
#  37.6547395,
#  37.6831552,
#  37.6312311266,
#  37.7054151818,
#  37.6927946,
#  37.6155771,
#  37.6583803846,
#  37.6645540055,
#  37.6673787916,
#  37.6192756,
#  37.6931261693,
#  37.6672997,
#  37.6816531,
#  37.6175351014,
#  37.6707056974,
#  37.6550432318,
#  37.6470962619,
#  37.6292705089,
#  37.6653813,
#  37.6174106969,
#  37.6555184,
#  37.6399356,
#  37.6175351014,
#  37.6140350057,
#  37.670704443,
#  37.6614886,
#  37.6809381,
#  37.6608223,
#  37.6749215504,
#  37.6254989841,
#  37.6790208492,
#  37.6940982,
#  37.6746843,
#  37.6770723,
#  37.6874592,
#  37.7149313,
#  37.6006961,
#  37.6588561,
#  37.633935495,
#  37.6524937,
#  37.6497789908,
#  37.6507482,
#  nan,
#  37.6694732913,
#  37.6635042264,
#  37.6858946979,
#  37.6625616531,
#  37.6388182315,
#  37.5998867006,
#  37.6738193,
#  37.6725555218,
#  37.6723467,
#  37.620278,
#  37.6543814,
#  37.6824317759,
#  37.6564072,
#  37.6912611,
# ...

# %%
lat = latitude

# %% [markdown]
# ### 경도 리스트 만들기

# %%
df_dict = goyang.to_dict()
dic_val = df_dict['WGS84경도'].values()
longitude = list(dic_val)

# %%
longitude
# Out:
# [126.7664115,
#  126.9018235658,
#  126.7647696,
#  126.8728368,
#  126.7836261,
#  126.7784297,
#  126.831064195,
#  126.9024807106,
#  126.7597724,
#  126.8346754,
#  126.7733747675,
#  126.7545272288,
#  126.7979039985,
#  126.8315975,
#  126.7675233585,
#  126.7990716,
#  126.7570994,
#  126.8462912478,
#  126.7581282251,
#  126.7744729433,
#  126.8948092677,
#  126.8687542134,
#  126.8157942,
#  126.8242081066,
#  126.8355939,
#  126.8320372,
#  126.8462912478,
#  126.8344814671,
#  126.7812146784,
#  126.7440193,
#  126.8139867,
#  126.7656566,
#  126.8081626599,
#  126.8169615534,
#  126.7936776896,
#  126.7628408,
#  126.7637081,
#  126.7509592,
#  126.777045,
#  126.851395,
#  126.8728368,
#  126.8384876,
#  126.8311306207,
#  126.8910022,
#  126.8700863528,
#  126.8843078,
#  nan,
#  126.7613834257,
#  126.7510116068,
#  126.7772800655,
#  126.7501934137,
#  126.7875971678,
#  126.8900147913,
#  126.7870725,
#  126.7570325665,
#  126.7573454,
#  126.8210724,
# ...

# %%
long = longitude

# %%
paw = 'paw',

# %%
icons = (paw * 117)
icons
# Out:
# ('paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
# ...

# %%
purple = 'purple',

# %%
colors = (purple * 117)
colors
# Out:
# ('purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
# ...

# %%
! pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ### 지도 표시하기

# %%
import folium

# %%
# lat, long,  names, icons,  colors

map_y = folium.Map([lat[0], long[0]], zoom_start=15)

for i in range(len(lat)):
    folium.Marker(
            [lat[i], long[i]], tooltip=names[i],
            icon=folium.Icon(color=colors[i], icon=icons[i], prefix='fa')
            ).add_to(map_y)
map_y
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [26], in <cell line: 5>()
#       3 map_y = folium.Map([lat[0], long[0]], zoom_start=15)
#       5 for i in range(len(lat)):
# ----> 6     folium.Marker(
#       7             [lat[i], long[i]], tooltip=names[i],
#       8             icon=folium.Icon(color=colors[i], icon=icons[i], prefix='fa')
#       9             ).add_to(map_y)
#      10 map_y
#
# File ~\AppData\Roaming\Python\Python39\site-packages\folium\map.py:280, in Marker.__init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     278 super(Marker, self).__init__()
#     279 self._name = 'Marker'
# --> 280 self.location = validate_location(location) if location else None
#     281 self.options = parse_options(
#     282     draggable=draggable or None,
#     283     autoPan=draggable or None,
#     284     **kwargs
#     285 )
# ...

# %%
import folium

map_y = folium.Map([lat[0], long[0]], zoom_start=15)

for i in range(len(lat)):
    folium.Marker(
            [lat[i], long[i]], tooltip=names[i],
            icon=folium.Icon(color=colors[i], icon=icons[i], prefix='fa')
            ).add_to(map_y)
map_y

# %%
names = ['Dr.JK 동물병원', '고양동물병원', '스마트동물병원', '경서동물병원', '신일산동물병원', '더독', '탑케어동물의료원', 
 '고양 우리아이 동물병원', '조이동물병원', '펫피아 동물병원', '제이엠 동물병원', '오엠동물병원', '풍동동물병원', '행신동물병원',
 '마리동물병원', '풍동 라파엘 동물병원', '워리워리', 'Helix ADI Center : 헬릭스 영상진단센터', '그랜드 동물병원', '24시 나음동물의료센터',
 '웰니스동물병원 스타필드 고양', '원흥동물의료센터', '해밀동물병원', '탑동물병원', '민동물병원', '화정동물병원', '헬릭스동물메디컬센터',
 '아이편한 동물의료센터', 'Dr. dog 동물영상의료센터', '쿨펫동물병원 킨텍스점', '위시티 동물병원', '수 동물병원', '에드워드동물병원',
 '해랑동물병원', '펫스티벌 동물병원', '조이동물병원 제니스점', '시민종합동물병원', '펫스마일동물병원', '현대동물병원', '펫앤유 24시 동물병원',
 '경서동물병원', '해오름 동물병원', 'FM 동물메디컬센터', '삼송동물병원', '고양시 동물보호센터', '삼송사랑 동물의료센터', '더바름동물병원',
 '쥬박스동물병원(탑동물병원)', '닥터서동물심장병원', '중산동물메디컬센터', '소노펫 동물병원', '새로이동물병원', '서울하은동물병원',
 '위즈펫동물병원 풍산점', '하노버', '호수동물병원', '작은 친구 동물병원', '삼송동물의료센터', '일산동물의료원', '원당동물병원',
 '해맑은 동물병원', '사과나무 동물병원', '포근한동물병원', '참사랑', '자유로 동물병원', '초원동물병원', '토베스트 동물병원',
 'Dr.dog동물의료센터', '토론토 동물병원', '튼튼동물병원', '강남동물병원', '신원동물메디컬센터', '올리브동물병원', '백마동물병원',
 '이창훈 동물병원', '일산 클래식 동물병원', '365 신원당 동물병원', '페로페라동물병원', '애니웰 동물병원', '쿨펫동물병원', '돌봄동물병원',
 '서울프라임 동물병원', '아마존', '산들동물병원', '앞선동물병원', '탄현 동물병원', '이용철동물병원', '거부기 동물병원', '로하스 동물병원',
 '이솝동물병원', '진스 종합 동물병원', '피그만클리닉', '가람동물병원', '메리알 동물병원', '다니엘 동물병원', '디엔씨', '소망 동물병원',
 '봄빛동물병원', '중산종합동물병원', '일산시티 동물의료센터', '통일로 동물병원', 'Wiz-Pet 동물병원', '동물진료법인 쥬박스동물메디컬센터',
 '센트럴동물병원', '24시 라인동물의료센터', '행신동물의료센터', '메리알동물병원', '지축오투동물의료센터', '리즈펫동물병원', '대심동물병원',
 '더힐링동물병원', '하이반려동물행동클리닉', '벳케어 동물병원', '반딧불 동물병원', '김 S 동물병원', '예 동물병원', '24일산우리동물병원']

# %%
lat = [37.6621933, 37.7010764859, 37.6617395, 37.6006961, 37.6547395, 37.6831552, 37.6312311266, 37.7054151818, 37.6927946, 37.6155771,
 37.6583803846, 37.6645540055, 37.6673787916, 37.6192756, 37.6931261693, 37.6672997, 37.6816531, 37.6175351014, 37.6707056974,
 37.6550432318, 37.6470962619, 37.6292705089, 37.6653813, 37.6174106969, 37.6555184, 37.6399356, 37.6175351014, 37.6140350057,
 37.670704443, 37.6614886, 37.6809381, 37.6608223, 37.6749215504, 37.6254989841, 37.6790208492, 37.6940982, 37.6746843, 37.6770723,
 37.6874592, 37.7149313, 37.6006961, 37.6588561, 37.633935495, 37.6524937, 37.6497789908, 37.6507482, 37.65033, 37.6694732913,
 37.6635042264, 37.6858946979, 37.6625616531, 37.6388182315, 37.5998867006, 37.6738193, 37.6725555218, 37.6723467, 37.620278,
 37.6543814, 37.6824317759, 37.6564072, 37.6912611, 37.6772424, 37.6481623, 37.6930436, 37.669548, 37.6795472, 37.6723519,
 37.6706401792, 37.6781278, 37.6418538178, 37.6787711, 37.6618789767, 37.6496256078, 37.6552376, 37.6693755, 37.6475958027,
 37.6543538, 37.6771875362, 37.6398309, 37.6328886, 37.6990711, 37.6274435, 37.6245795, 37.6820201, 37.6617165, 37.6985487186,
 37.6836565405, 37.6618944881, 37.6695112639, 37.6616277, 37.6501845, 37.6528963832, 37.6543794, 37.6399409, 37.6567391,
 37.6234997889, 37.6764934, 37.6476034, 37.6858946979, 37.6601492727, 37.687798, 37.6431641, 37.6694732913, 37.6380537487,
 37.6524252132, 37.6235052997, 37.613426731, 37.64878743, 37.6495732412, 37.6871028144, 37.6601067159, 37.6504664009, 37.6870729,
 37.6703244, 37.666658318, 37.6302983, 37.6708974586]

# %%
long = [126.7664115, 126.9018235658, 126.7647696, 126.8728368, 126.7836261, 126.7784297, 126.831064195, 126.9024807106, 126.7597724,
 126.8346754, 126.7733747675, 126.7545272288, 126.7979039985, 126.8315975, 126.7675233585, 126.7990716, 126.7570994, 126.8462912478,
 126.7581282251, 126.7744729433, 126.8948092677, 126.8687542134, 126.8157942, 126.8242081066, 126.8355939, 126.8320372,
 126.8462912478, 126.8344814671, 126.7812146784, 126.7440193, 126.8139867, 126.7656566, 126.8081626599, 126.8169615534,
 126.7936776896, 126.7628408, 126.7637081, 126.7509592, 126.777045, 126.851395, 126.8728368, 126.8384876, 126.8311306207,
 126.8910022, 126.8700863528, 126.8843078, 126.89954, 126.7613834257, 126.7510116068, 126.7772800655, 126.7501934137, 126.7875971678,
 126.8900147913, 126.7870725, 126.7570325665, 126.7573454, 126.8210724, 126.8960875, 126.7538266641, 126.8333707, 126.7632694,
 126.7679054, 126.884176, 126.780985, 126.7340737, 126.7626043, 126.7780429, 126.7810225333, 126.7558527, 126.7872848107,
 126.8110676, 126.8880641812, 126.7802502896, 126.7899027, 126.7763517, 126.7829110755, 126.8403447, 126.8123752763, 126.7898787,
 126.8310678, 126.753935, 126.8288713, 126.8358671, 126.7784898, 126.887781, 126.7655302945, 126.7724137723, 126.7659256092,
 126.7674720555, 126.7862125, 126.7761267, 126.8992287721, 126.7789583, 126.7859583, 126.7882099, 126.8362215426, 126.8121843,
 126.7882929, 126.7772800655, 126.76646432, 126.8693064, 126.789654, 126.7613834257, 126.8328459978, 126.8969766222, 126.834000425,
 126.833705087, 126.9174219266, 126.8962401729, 126.8666972136, 126.908082011, 126.8756238994, 126.7191928, 126.759687,
 126.7735945149, 126.8694207, 126.7585231859]

# %%
paw = 'paw',

# %%
icons = (paw * 117)
icons
# Out:
# ('paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
#  'paw',
# ...

# %%
purple = 'purple',

# %%
colors = (purple * 117)
colors
# Out:
# ('purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
#  'purple',
# ...

# %%
# lat, long,  names, icons,  colors

map_y = folium.Map([lat[0], long[0]], zoom_start=15)

for i in range(len(lat)):
    folium.Marker(
            [lat[i], long[i]], tooltip=names[i],
            icon=folium.Icon(color=colors[i], icon=icons[i], prefix='fa')
            ).add_to(map_y)
map_y
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# pet = pd.read_csv('data/반려동물등록현황.csv', encoding='euc-kr')
# pet

# %%
population = pd.read_csv('data/주민등록인구집계현황.csv', encoding='euc-kr')
population.head(2)

# %%
mean_age = pd.read_csv('data/평균연령집계현황.csv', encoding='euc-kr')
mean_age

# %%
# 주민등록인구 집계현황, 평균연령 집계현황 합치기 
pop = pd.merge(mean_age, population)
pop

# %%
office = pd.read_csv('data/경기도청사및출장소현황.csv', encoding='euc-kr')
office

# %%
# 사이트에 자료 요청
import urllib.request
# json 데이터 핸들링
import json
# DataFrame 자료형 활용
import pandas as pd
# json 데이터를 pandas DataFrame으로 변환
from pandas.io.json import json_normalize

# %%
key = '3dc7bb9e48f744e5b5c1f9399829999d'
target_dt = '20220315'
url ="https://openapi.gg.go.kr/AnimalRegistStus?key=%s&targetDt=%s" % (key, target_dt)
    
url

# %%
result = urllib.request.urlopen(url)

# %%
json_raw_data = result.read()

# %%
result.read()

# %%
type(json_raw_data)

# %%
json_utf8 = json_raw_data.decode('utf-8')

# %%
json_utf8

# %%
type(json_utf8)

# %%
json_complete = json.loads(json_utf8)
