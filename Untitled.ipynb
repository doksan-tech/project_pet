# %%
import numpy as np
import pandas as pd

# %%
store = pd.read_csv('data/반려동물판매업체현황.csv', encoding='cp949')
store
# Out:
#        시군명               사업장명     인허가일자  인허가취소일자  영업상태구분코드 영업상태명        폐업일자  \
# 0      가평군              예쁜강아지  20080909      NaN         4    말소  20220526.0
# 1      가평군             자이언트 펫  20160517      NaN         4    말소  20220526.0
# 2      가평군              메이플켄넬  20170227      NaN         4    말소         NaN
# 3      가평군               리얼펫독  20150120      NaN         4    말소  20220526.0
# 4      가평군              강아지나라  20100311      NaN         4    말소  20220526.0
# ...    ...                ...       ...      ...       ...   ...         ...
# 14449  화성시             금은이네농장  20211119      NaN         2    폐업  20220728.0
# 14450  화성시             냥이와 양이  20170530      NaN         1    휴업         NaN
# 14451  NaN  학교종이 댕댕댕(24거3849)  20200909      NaN         4    말소  20220526.0
# 14452  NaN               쁘띠살롱  20220126      NaN         4    말소  20220526.0
# 14453  NaN  학교종이 댕댕댕(24거3849)  20200909      NaN         4    말소  20220701.0
#
#           소재지시설전화번호  소재지면적정보  도로명우편번호  ...                    소재지지번주소  \
# 0               NaN      NaN      NaN  ...   경기도 가평군 가평읍 읍내리 ***-*번지
# 1      031-585-7003      0.0  12457.0  ...  경기도 가평군 청평면 대성리 ***-**번지
# 2          585-0588      0.0  12416.0  ...     경기도 가평군 가평읍 대곡리 ***-*
# 3               NaN      0.0  12467.0  ...     경기도 가평군 설악면 신천리 ***-*
# 4               NaN      NaN      NaN  ...  경기도 가평군 청평면 청평리 ***-**번지
# ...             ...      ...      ...  ...                        ...
# 14449           NaN      0.0  18562.0  ...       경기도 화성시 우정읍 운평리 ***
# 14450           NaN      0.0  18556.0  ...     경기도 화성시 서신면 홍법리 ***-*
# 14451           NaN      0.0  31560.0  ...         충청남도 아산시 법곡동 *-**
# 14452           NaN      0.0  21548.0  ...       인천광역시 남동구 구월동 **-**
# 14453           NaN      0.0  31560.0  ...         충청남도 아산시 법곡동 *-**
#
#        소재지우편번호  WGS84위도  WGS84경도  업태구분명정보           X좌표값           Y좌표값  \
# 0          NaN      NaN      NaN      NaN  245212.733716  480846.133947
# 1      12457.0      NaN      NaN      NaN  233842.021227  466192.802959
# 2          NaN      NaN      NaN      NaN  243247.301370  480064.513852
# 3          NaN      NaN      NaN      NaN  243200.199051  463336.290376
# 4          NaN      NaN      NaN      NaN  236894.589288  470644.366611
# ...        ...      ...      ...      ...            ...            ...
# 14449  18562.0      NaN      NaN      NaN  180335.240868  397423.594307
# 14450  18556.0      NaN      NaN      NaN  175386.850094  407462.012505
# 14451  31560.0      NaN      NaN      NaN  201030.437190  362598.297324
# 14452      NaN      NaN      NaN      NaN  174682.069911  439615.145968
# 14453  31560.0      NaN      NaN      NaN  201030.437190  362598.297324
#
#        축산업무구분명 축산고유번호  권리주체일련번호
# 0       동물관련영업    NaN       000
# 1       동물관련영업    NaN       000
# 2       동물관련영업    0.0       000
# 3       동물관련영업    NaN       000
# 4       동물관련영업    NaN       000
# ...        ...    ...       ...
# 14449   동물관련영업    0.0       000
# 14450   동물관련영업    0.0       000
# 14451   동물관련영업    NaN       000
# 14452   동물관련영업    0.0       000
# 14453      NaN    NaN       NaN
#
# [14454 rows x 21 columns]

# %%
pet = pd.read_csv('data/반려동물등록현황.csv', encoding='euc-kr')
pet
# Out:
#      시군명 읍면동명  등록동물수(마리)  (등록주체)시군구등록  (등록주체)대행업체등록  (등록주체)기타  (RFID종류)내장형  \
# 0    가평군  가평읍        941          NaN           NaN       NaN          596
# 1    가평군   북면        289          NaN           NaN       NaN          176
# 2    가평군   상면        399          NaN           NaN       NaN          217
# 3    가평군  설악면       1111          NaN           NaN       NaN          446
# 4    가평군  조종면        416          NaN           NaN       NaN          218
# ..   ...  ...        ...          ...           ...       ...          ...
# 724  화성시  청계동       2046         90.0        1956.0       0.0         1052
# 725  화성시  팔탄면        753         87.0         665.0       1.0          345
# 726  화성시  향남읍       5180        314.0        4863.0       3.0         2110
# 727  화성시  활초동         15          0.0          15.0       0.0            4
# 728  화성시  황계동         52         16.0          36.0       0.0           19
#
#      (RFID종류)외장형  (RFID종류)인식표  등록품종수  등록소유자수  동물소유자당등록동물수  해당동의등록대행업체수  \
# 0            294           51    NaN    85.0          NaN          3.0
# 1             93           20    NaN   185.0          NaN          0.0
# 2            153           29    NaN   243.0          NaN          0.0
# 3            612           53    NaN   625.0          NaN          1.0
# 4            161           37    NaN   274.0          NaN          1.0
# ..           ...          ...    ...     ...          ...          ...
# 724          879          115   66.0  1679.0         1.22          4.0
# 725          305          103   62.0   412.0         1.83          1.0
# 726         2584          486  103.0  3719.0         1.39          6.0
# 727           11            0    7.0    11.0         1.36          0.0
# 728           13           20   15.0    24.0         2.17          0.0
#
#         데이터기준일자
# 0    2022-06-14
# 1    2022-06-14
# 2    2022-06-14
# 3    2022-06-14
# 4    2022-06-14
# ..          ...
# 724  2022-05-31
# 725  2022-05-31
# 726  2022-05-31
# 727  2022-05-31
# 728  2022-05-31
#
# [729 rows x 14 columns]

# %%
population = pd.read_csv('data/주민등록인구집계현황.csv', encoding='euc-kr')
population.head(2)
# Out:
#      연도  월 행정구역구분명     행정구역명     총 인구수     0~9세   10~19세   20~29세   30~39세  \
# 0  2022  9       도     경기도    13574353  1054380  1327378  1753988  1880750
# 1  2022  9      시군  경기도 가평군      62168     3047     4471     6009     5406
#
#     40~49세  ...  10~19세 (여)  20~29세 (여)  30~39세 (여)  40~49세 (여)  50~59세 (여)  \
# 0  2286448  ...      646493      828547      904145     1122988     1131303
# 1     7722  ...        2175        2520        2449        3575        5177
#
#    60~69세 (여)  70~79세 (여)  80~89세 (여)  90~99세 (여)  100세 이상 (여)
# 0      864393      435119      248574       43544         1373
# 1        6376        3551        2379         395           15
#
# [2 rows x 40 columns]

# %%
mean_age = pd.read_csv('data/평균연령집계현황.csv', encoding='euc-kr')
mean_age
# Out:
#           연도  월 행정구역구분명        행정구역명  남자 평균연령  여자 평균연령  평균연령
# 0       2022  9       도        경기도       41.4     43.2  42.3
# 1       2022  9      시군     경기도 가평군      49.1     51.6  50.3
# 2       2022  9     읍면동  경기도 가평군 가평읍     46.9     49.7  48.3
# 3       2022  9     읍면동   경기도 가평군 북면     55.0     57.9  56.4
# 4       2022  9     읍면동   경기도 가평군 상면     52.8     56.9  54.7
# ...      ... ..     ...          ...      ...      ...   ...
# 106353  2008  1     읍면동  경기도 화성시 정남면     37.2     40.2  38.6
# 106354  2008  1     읍면동  경기도 화성시 진안동     30.2     31.2  30.7
# 106355  2008  1     읍면동  경기도 화성시 팔탄면     38.4     41.5  39.7
# 106356  2008  1     읍면동  경기도 화성시 향남읍     34.9     37.0  35.9
# 106357  2008  1     읍면동  경기도 화성시 화산동     32.5     33.5  33.0
#
# [106358 rows x 7 columns]

# %%
# 주민등록인구 집계현황, 평균연령 집계현황 합치기 
pop = pd.merge(mean_age, population)
pop
# Out:
#           연도  월 행정구역구분명        행정구역명  남자 평균연령  여자 평균연령  평균연령     총 인구수  \
# 0       2022  9       도        경기도       41.4     43.2  42.3  13574353
# 1       2022  9      시군     경기도 가평군      49.1     51.6  50.3     62168
# 2       2022  9     읍면동  경기도 가평군 가평읍     46.9     49.7  48.3     19532
# 3       2022  9     읍면동   경기도 가평군 북면     55.0     57.9  56.4      3821
# 4       2022  9     읍면동   경기도 가평군 상면     52.8     56.9  54.7      5688
# ...      ... ..     ...          ...      ...      ...   ...       ...
# 106624  2008  1     읍면동  경기도 화성시 팔탄면     38.4     41.5  39.7      9900
# 106625  2008  1     읍면동  경기도 화성시 향남읍     34.9     37.0  35.9     21100
# 106626  2008  1     읍면동  경기도 화성시 향남읍     34.9     37.0  35.9     21100
# 106627  2008  1     읍면동  경기도 화성시 화산동     32.5     33.5  33.0     23684
# 106628  2008  1     읍면동  경기도 화성시 화산동     32.5     33.5  33.0     23684
#
#            0~9세   10~19세  ...  10~19세 (여)  20~29세 (여)  30~39세 (여)  40~49세 (여)  \
# 0       1054380  1327378  ...      646493      828547      904145     1122988
# 1          3047     4471  ...        2175        2520        2449        3575
# 2          1062     1677  ...         784         959         845        1245
# 3           126      177  ...          90          82          99         164
# 4           153      244  ...         111         155         171         245
# ...         ...      ...  ...         ...         ...         ...         ...
# 106624      869      869  ...         407         606         596         717
# 106625     2828     2288  ...        1136        1444        1835        1467
# 106626     2828     2288  ...        1136        1444        1835        1467
# 106627     3727     2793  ...        1296        1699        2528        1737
# 106628     3727     2793  ...        1296        1699        2528        1737
#
#         50~59세 (여)  60~69세 (여)  70~79세 (여)  80~89세 (여)  90~99세 (여)  \
# 0          1131303      864393      435119      248574       43544
# 1             5177        6376        3551        2379         395
# 2             1590        1792        1013         732         117
# 3              309         507         288         206          39
# 4              543         718         384         240          44
# ...            ...         ...         ...         ...         ...
# 106624         579         455         373         120          23
# 106625        1107         797         622         180          34
# 106626        1107         797         622         180          34
# 106627        1079         686         419         115          19
# 106628        1079         686         419         115          19
#
#         100세 이상 (여)
# 0              1373
# 1                15
# 2                 7
# 3                 1
# 4                 0
# ...             ...
# 106624            0
# 106625            4
# 106626            4
# 106627            0
# 106628            0
#
# [106629 rows x 43 columns]

# %%
office = pd.read_csv('data/경기도청사및출장소현황.csv', encoding='euc-kr')
office
# Out:
#            집계일자  시군명         구분명         전화번호안내  소재지우편번호  \
# 0    2022-05-06  광명시        철산2동   02-2680-6609    14215
# 1    2022-05-06  광명시         일직동   02-2680-5800    14345
# 2    2022-04-16  오산시   남촌동행정복지센터  031-8036-6260    18119
# 3    2022-04-16  오산시   세마동행정복지센터  031-8036-6327    18105
# 4    2022-04-16  오산시  오산시차량등록사업소  031-8036-6090    18119
# ..          ...  ...         ...            ...      ...
# 828  2015-09-18  포천시         이동면   031-538-3909   487863
# 829  2015-09-18  포천시         가산면   031-538-3904   487814
# 830  2015-09-18  포천시         화현면   031-538-3912   487841
# 831  2015-09-18  포천시         내촌면   031-538-3903   487831
# 832  2015-09-18  포천시         선단동   031-538-3914   487020
#
#                         소재지도로명주소                  소재지지번주소    WGS84위도  \
# 0                 경기도 광명시 시청로 61      경기도 광명시 철산동 160-4번지  37.484689
# 1              경기도 광명시 양지로 19 6층   경기도 광명시 일직동 512-3번지 6층  37.418938
# 2         경기도 오산시 청학로 55-5 (청학동)         경기도 오산시 청학동 16-6  37.154587
# 3         경기도 오산시 독산성로 419 (세교동)        경기도 오산시 세교동 595-2  37.188300
# 4             경기도 오산시 청학로 98(궐동)            경기도 오산시 궐동 94  37.157522
# ..                           ...                      ...        ...
# 828   경기도 포천시 이동면 화동로 2048 (장암리)  경기도 포천시 이동면 장암리 245-3번지  38.030721
# 829    경기도 포천시 가산면 선마로 223 (마산리)  경기도 포천시 가산면 마산리 601-1번지  37.848210
# 830  경기도 포천시 화현면 달인동로1길 55 (화현리)    경기도 포천시 화현면 화현리 873번지  37.901193
# 831      경기도 포천시 내촌면 내촌로 70 (내리)   경기도 포천시 내촌면 내리 368-5번지  37.786139
# 832  경기도 포천시 삼육사로2186번길 11 (선단동)        경기도 포천시 선단동 631번지  37.854174
#
#         WGS84경도
# 0    126.866622
# 1    126.882693
# 2    127.063455
# 3    127.040824
# 4    127.065117
# ..          ...
# 828  127.367306
# 829  127.186145
# 830  127.288076
# 831  127.228592
# 832  127.159171
#
# [833 rows x 9 columns]

# %%
! pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in c:\users\playdata\appdata\roaming\python\python39\site-packages (0.13.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.21.5)
# Requirement already satisfied: branca>=0.3.0 in c:\users\playdata\appdata\roaming\python\python39\site-packages (from folium) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.3)

# %%
import folium

# %%
lat1, long1 = 37.38329, 127.12061

map_y = folium.Map([lat1, long1], zoom_start = 15)
folium.Marker([lat1, long1], tooltip='분당구청 사거리').add_to(map_y)

map_y
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8cd4ca83864cfa67d862edcd89f1e357 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8cd4ca83864cfa67d862edcd89f1e357&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8cd4ca83864cfa67d862edcd89f1e357 = L.map(
#                 &quot;map_8cd4ca83864cfa67d862edcd89f1e357&quot;,
#                 {
#                     center: [37.38329, 127.12061],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8be5e5a52a2cc33fa37fedf6950ae938 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8cd4ca83864cfa67d862edcd89f1e357);
#
#
#             var marker_d0717aaaf62a90bfff5e8c1759932fba = L.marker(
#                 [37.38329, 127.12061],
#                 {}
#             ).addTo(map_8cd4ca83864cfa67d862edcd89f1e357);
#
#
#             marker_d0717aaaf62a90bfff5e8c1759932fba.bindTooltip(
#                 `&lt;div&gt;
#                      분당구청 사거리
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_y = folium.Map([37.38329, 127.12061], zoom_start = 15)
map_y
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9ace96df4a30f83eaae6858824e42ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9ace96df4a30f83eaae6858824e42ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c9ace96df4a30f83eaae6858824e42ea = L.map(
#                 &quot;map_c9ace96df4a30f83eaae6858824e42ea&quot;,
#                 {
#                     center: [37.38329, 127.12061],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e9335f13bbab317307c9b324ca7cb5e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c9ace96df4a30f83eaae6858824e42ea);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lat1, long1 = 37.52860, 126.93431
lat2, long2 = 37.52400, 126.91889

map_y = folium.Map([lat1, long1], zoom_start = 15)
folium.Marker([lat1, long1], tooltip='여의도 한강공원', icon=folium.Icon(color='purple', icon='map', prefix='fa')).add_to(map_y)
folium.Marker([lat2, long2], tooltip='여의도 공원', icon=folium.Icon(color='purple', icon='map', prefix='fa')).add_to(map_y)
map_y
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bcc165e277cb8dce38e05ba9d19d812 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bcc165e277cb8dce38e05ba9d19d812&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4bcc165e277cb8dce38e05ba9d19d812 = L.map(
#                 &quot;map_4bcc165e277cb8dce38e05ba9d19d812&quot;,
#                 {
#                     center: [37.5286, 126.93431],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_519b31ad19e736a796dc19354ea59e4d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4bcc165e277cb8dce38e05ba9d19d812);
#
#
#             var marker_f3e729e199164cf8806303316900b489 = L.marker(
#                 [37.5286, 126.93431],
#                 {}
#             ).addTo(map_4bcc165e277cb8dce38e05ba9d19d812);
#
#
#             var icon_aeec15b8466e6caf26b893275503752f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f3e729e199164cf8806303316900b489.setIcon(icon_aeec15b8466e6caf26b893275503752f);
#
#
#             marker_f3e729e199164cf8806303316900b489.bindTooltip(
#                 `&lt;div&gt;
#                      여의도 한강공원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_231cfa5c0780233d5c41db585f1e5513 = L.marker(
#                 [37.524, 126.91889],
#                 {}
#             ).addTo(map_4bcc165e277cb8dce38e05ba9d19d812);
#
#
#             var icon_096038226934110d5890eaf8cdde51ca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_231cfa5c0780233d5c41db585f1e5513.setIcon(icon_096038226934110d5890eaf8cdde51ca);
#
#
#             marker_231cfa5c0780233d5c41db585f1e5513.bindTooltip(
#                 `&lt;div&gt;
#                      여의도 공원
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 사이트에 자료 요청
import urllib.request
# json 데이터 핸들링
import json
# DataFrame 자료형 활용
import pandas as pd
# json 데이터를 pandas DataFrame으로 변환
from pandas.io.json import json_normalize

# %%
key = '3dc7bb9e48f744e5b5c1f9399829999d'
target_dt = '20220315'
url ="https://openapi.gg.go.kr/AnimalRegistStus?key=%s&targetDt=%s" % (key, target_dt)
    
url
# Out:
# 'https://openapi.gg.go.kr/AnimalRegistStus?key=3dc7bb9e48f744e5b5c1f9399829999d&targetDt=20220315'

# %%
result = urllib.request.urlopen(url)

# %%
json_raw_data = result.read()

# %%
result.read()
# Out:
# b''

# %%
type(json_raw_data)
# Out:
# bytes

# %%
json_utf8 = json_raw_data.decode('utf-8')

# %%
json_utf8
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n\n<AnimalRegistStus>\n  <head>\n    <list_total_count>729</list_total_count>\n    <RESULT>\n      <CODE>INFO-000</CODE>\n      <MESSAGE>정상 처리되었습니다.</MESSAGE>\n    </RESULT>\n    <api_version>1.0v</api_version>\n  </head>\n  <row>\n    <SIGUN_CD>41110</SIGUN_CD>\n    <DATA_STD_DE>2021-06-18</DATA_STD_DE>\n    <EMD_NM>우만동</EMD_NM>\n    <REGIST_ANIMAL_CNT>2157</REGIST_ANIMAL_CNT>\n    <SIGNGU_REGIST_CNT>227</SIGNGU_REGIST_CNT>\n    <ACTING_ENTRPS_REGIST_CNT>1930</ACTING_ENTRPS_REGIST_CNT>\n    <ETC_REGIST_CNT>0</ETC_REGIST_CNT>\n    <RFID_ISE_DEVICE_SHP_CNT>1334</RFID_ISE_DEVICE_SHP_CNT>\n    <RFID_TOS_DEVICE_SHP_CNT>604</RFID_TOS_DEVICE_SHP_CNT>\n    <RFID_PPSTMP_SHP_CNT>219</RFID_PPSTMP_SHP_CNT>\n    <ANIMAL_SPECIES_CNT>72</ANIMAL_SPECIES_CNT>\n    <ANIMAL_OWNER_CNT>1648</ANIMAL_OWNER_CNT>\n    <OWNER_REGIST_ANIMAL_CNT_VL>1.31</OWNER_REGIST_ANIMAL_CNT_VL>\n    <REGIST_ACTING_ENTRPS_CNT>1</REGIST_ACTING_ENTRPS_CNT>\n    <SIGUN_NM>수원시</SIGUN_NM>\n  </row>\n  <row>\n    <SIGUN_CD>41110</SIGUN_CD>\n    <DATA_STD_DE>2021-06-18</DATA_STD_DE>\n    <EMD_NM>인계동</EMD_NM>\n    <REGIST_ANIMAL_CNT>3102</REGIST_ANIMAL_CNT>\n    <SIGNGU_REGIST_CNT>167</SIGNGU_REGIST_CNT>\n    <ACTING_ENTRPS_REGIST_CNT>2925</ACTING_ENTRPS_REGIST_CNT>\n    <ETC_REGIST_CNT>10</ETC_REGIST_CNT>\n    <RFID_ISE_DEVICE_SHP_CNT>2153</RFID_ISE_DEVICE_SHP_CNT>\n    <RFID_TOS_DEVICE_SHP_CNT>687</RFID_TOS_DEVICE_SHP_CNT>\n    <RFID_PPSTMP_SHP_CNT>262</RFID_PPSTMP_SHP_CNT>\n    <ANIMAL_SPECIES_CNT>75</ANIMAL_SPECIES_CNT>\n    <ANIMAL_OWNER_CNT>2303</ANIMAL_OWNER_CNT>\n    <OWNER_REGIST_ANIMAL_CNT_VL>1.35</OWNER_REGIST_ANIMAL_CNT_VL>\n    <REGIST_ACTING_ENTRPS_CNT>8</REGIST_ACTING_ENTRPS_CNT>\n    <SIGUN_NM>수원시</SIGUN_NM>\n  </row>\n  <row>\n    <SIGUN_CD>41110</SIGUN_CD>\n    <DATA_STD_DE>2021-06-18</DATA_STD_DE>\n    <EMD_NM>장안동</EMD_NM>\n    <REGIST_ANIMAL_CNT>77</REGIST_ANIMAL_CNT>\n    <SIGNGU_REGIST_CNT>9</SIGNGU_REGIST_CNT>\n    <ACTING_ENTRPS_REGIST_CNT>68</ACTING_ENTRPS_REGIST_CNT>\n    <ETC_REGIST_CNT>0</ETC_REGIST_CNT>\n    <RFID_ISE_DEVICE_SHP_CNT>50</RFID_ISE_DEVICE_SHP_CNT>\n    <RFID_TOS_DEVICE_SHP_CNT>17</RFID_TOS_DEVICE_SHP_CNT>\n    <RFID_PPSTMP_SHP_CNT>10</RFID_PPSTMP_SHP_CNT>\n    <ANIMAL_SPECIES_CNT>21</ANIMAL_SPECIES_CNT>\n    <ANIMAL_OWNER_CNT>58</ANIMAL_OWNER_CNT>\n    <OWNER_REGIST_ANIMAL_CNT_VL>1.33</OWNER_REGIST_ANIMAL_CNT_VL>\n    <REGIST_ACTING_ENTRPS_CNT>0</REGIST_ACTING_ENTRPS_CNT>\n    <SIGUN_NM>수원시</SIGUN_NM>\n  </row>\n  <row>\n    <SIGUN_CD>41110</SIGUN_CD>\n    <DATA_STD_DE>2021-06-18</DATA_STD_DE>\n    <EMD_NM>화서동</EMD_NM>\n    <REGIST_ANIMAL_CNT>2752</REGIST_ANIMAL_CNT>\n    <SIGNGU_REGIST_CNT>221</SIGNGU_REGIST_CNT>\n    <ACTING_ENTRPS_REGIST_CNT>2508</ACTING_ENTRPS_REGIST_CNT>\n    <ETC_REGIST_CNT>23</ETC_REGIST_CNT>\n    <RFID_ISE_DEVICE_SHP_CNT>1774</RFID_ISE_DEVICE_SHP_CNT>\n    <RFID_TOS_DEVICE_SHP_CNT>671</RFID_TOS_DEVICE_SHP_CNT>\n    <RFID_PPSTMP_SHP_CNT>307</RFID_PPSTMP_SHP_CNT>\n    <ANIMAL_SPECIES_CNT>67</ANIMAL_SPECIES_CNT>\n    <ANIMAL_OWNER_CNT>2158</ANIMAL_OWNER_CNT>\n    <OWNER_REGIST_ANIMAL_CNT_VL>1.27</OWNER_REGIST_ANIMAL_CNT_VL>\n    <REGIST_ACTING_ENTRPS_CNT>4</REGIST_ACTING_ENTRPS_CNT>\n    <SIGUN_NM>수원시</SIGUN_NM>\n  </row>\n  <row>\n    <SIGUN_CD>41110</SIGUN_CD>\n    <DATA_STD_DE>2021-06-18</DATA_STD_DE>\n    <EMD_NM>매산로1가</EMD_NM>\n    <REGIST_ANIMAL_CNT>157</REGIST_ANIMAL_CNT>\n    <SIGNGU_REGIST_CNT>22</SIGNGU_REGIST_CNT>\n    <ACTING_ENTRPS_REGIST_CNT>134</ACTING_ENTRPS_REGIST_CNT>\n    <ETC_REGIST_CNT>1</ETC_REGIST_CNT>\n    <RFID_ISE_DEVICE_SHP_CNT>89</RFID_ISE_DEVICE_SHP_CNT>\n    <RFID_TOS_DEVICE_SHP_CNT>47</RFID_TOS_DEVICE_SHP_CNT>\n    <RFID_PPSTMP_SHP_CNT>21</RFID_PPSTMP_SHP_CNT>\n    <ANIMAL_SPECIES_CNT>27</ANIMAL_SPECIES_CNT>\n    <ANIMAL_OWNER_CNT>95</ANIMAL_OWNER_CNT>\n    <OWNER_REGIST_ANIMAL_CNT_VL>1.65</OWNER_REGIST_ANIMAL_CNT_VL>\n    <REGIST_ACTING_ENTRPS_CNT>0</REGIST_ACTING_ENTRPS_CNT>\n    <SIGUN_NM>수원시</SIGUN_NM>\n  </row>\n  <row>\n    <SIGUN_CD>4 ...

# %%
type(json_utf8)
# Out:
# str

# %%
json_complete = json.loads(json_utf8)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 json_complete = json.loads(json_utf8)
#
# File C:\ProgramData\Anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File C:\ProgramData\Anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File C:\ProgramData\Anaconda3\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import xml.etree.ElementTree as et

# %%
xtree= et.parse("json_utf8")
xroot= xtree.getroot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 xtree= et.parse("json_utf8")
#       2 xroot= xtree.getroot()
#
# File C:\ProgramData\Anaconda3\lib\xml\etree\ElementTree.py:1229, in parse(source, parser)
#    1220 """Parse XML document into element tree.
#    1221
#    1222 *source* is a filename or file object containing XML data,
#    (...)
#    1226
#    1227 """
#    1228 tree = ElementTree()
# -> 1229 tree.parse(source, parser)
#    1230 return tree
#
# File C:\ProgramData\Anaconda3\lib\xml\etree\ElementTree.py:569, in ElementTree.parse(self, source, parser)
#     567 close_source = False
#     568 if not hasattr(source, "read"):
# --> 569     source = open(source, "rb")
#     570     close_source = True
#     571 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'json_utf8'

# %%
! pip3 install xmltodict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %%
import xmltodict
import json
